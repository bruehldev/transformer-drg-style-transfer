# %% [markdown]
# ## Prepare Referece files using TFIDF for retrieving attributes

# %%
import pandas as pd
from tqdm import tqdm, trange
import numpy as np
import time
import torch
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def read_file(path):
    with open(path) as fp:
        lines = fp.read().splitlines()
    return lines

# %%
def clean_text(text):
    return text.replace("<POS>","").replace("<NEG>","").replace("<CON_START>","").replace("<START>","").replace("<END>","").strip()

# %%
data_dir = "/home/jack/Desktop/NN/clean/datasets/yelp"

train0_org = read_file(data_dir+"/sentiment.train.0") # Training data of negative sentiment
train1_org = read_file(data_dir+"/sentiment.train.1") # Training data of positive sentiment
ref0_processed = read_file(data_dir+"/processed_files_with_bert_with_best_head/reference_0.txt") # Reference data for delete_generate model
ref1_processed = read_file(data_dir+"/processed_files_with_bert_with_best_head/reference_1.txt") # Reference data for delete_generate model
ref0_org = read_file(data_dir+"/reference.0") # Original Refrence_0 data
ref1_org = read_file(data_dir+"/reference.1") # Original Refrence_1 data
train0_processed = read_file(data_dir+"/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_train_0_all_attrs.txt") # training data with content and attributes seperation
train1_processed = read_file(data_dir+"/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/sentiment_train_1_all_attrs.txt") # training data with content and attributes seperation

# %%
# Get the Original Reference Sentence
ref0_org = [x.split("\t")[0] for x in ref0_org]
ref1_org = [x.split("\t")[0] for x in ref1_org]

# %%
# Get the Content of the Reference Sentences
ref0_con = [clean_text(x) for x in ref0_processed]
ref1_con = [clean_text(x) for x in ref1_processed]

# %%
ref0_org[:4], ref0_con[:4]
# Out:
# (["ever since joes has changed hands it 's just gotten worse and worse .",
#   'there is definitely not enough room in that part of the venue .',
#   'so basically tasted watered down .',
#   "she said she 'd be back and disappeared for a few minutes ."],
#  ["ever since joes has changed hands it ' just gotten and .",
#   'there is not enough room in that part of the .',
#   'so basically down .',
#   "she she ' d be back and for a few ."])

# %%
def get_train_content(text):
    return text.split("<START>")[0].split("<CON_START>")[1].strip()

# %%
def get_train_attrs(text):
    return text.split("<CON_START>")[0].replace("<ATTR_WORDS>","").strip().split()

# %%
get_train_attrs(train0_processed[0])
# Out:
# ['sadly']

# %%
train0_processed[:4], train1_processed[:4]
# Out:
# (['<ATTR_WORDS> sadly <CON_START> i was mistaken . <START> i was sadly mistaken . <END>',
#   '<ATTR_WORDS> so run mill <CON_START> on to the hoagies , the italian is general of the . <START> so on to the hoagies , the italian is general run of the mill . <END>',
#   '<ATTR_WORDS> minimal ton <CON_START> meat and a of shredded lettuce . <START> minimal meat and a ton of shredded lettuce . <END>',
#   '<ATTR_WORDS> nothing really worthy _num_ <CON_START> special & not of the $ _ num _ price tag . <START> nothing really special & not worthy of the $ _num_ price tag . <END>'],
#  ['<ATTR_WORDS> excellent <CON_START> food . <START> excellent food . <END>',
#   '<ATTR_WORDS> superb <CON_START> customer service . <START> superb customer service . <END>',
#   '<ATTR_WORDS> daily really good <CON_START> they also have specials and ice cream which is . <START> they also have daily specials and ice cream which is really good . <END>',
#   "<ATTR_WORDS> 's good <CON_START> it ' a toasted hoagie . <START> it 's a good toasted hoagie . <END>"])

# %%
# get content
train0_con = [get_train_content(x) for x in train0_processed]
train1_con = [get_train_content(x) for x in train1_processed]

# %%
train0_con[:4], train1_con[:4]
# Out:
# (['i was mistaken .',
#   'on to the hoagies , the italian is general of the .',
#   'meat and a of shredded lettuce .',
#   'special & not of the $ _ num _ price tag .'],
#  ['food .',
#   'customer service .',
#   'they also have specials and ice cream which is .',
#   "it ' a toasted hoagie ."])

# %%
# Fatch attributes from the training data
attrs_neg = [get_train_attrs(x) for x in train0_processed]
attrs_pos = [get_train_attrs(x) for x in train1_processed]

# %%
# Get TFIDF vectors for Training and Reference
tfidf = TfidfVectorizer()
conts_vecs = tfidf.fit_transform(train0_con + train1_con)
conts_pos_vecs = conts_vecs[:len(train1_con)]
conts_neg_vecs = conts_vecs[len(train1_con):len(train1_con)+len(train0_con)]
conts_from_pos_ref_vecs = tfidf.transform(ref1_con)
conts_from_neg_ref_vecs = tfidf.transform(ref0_con)

# %% [markdown]
# #### AnnoyIndex is used to store the TFIDF vectors of training set and retrieve nearest neighbours of the reference content

# %%
from annoy import AnnoyIndex

# %%
train0_tree = AnnoyIndex(conts_neg_vecs.shape[-1])
train1_tree = AnnoyIndex(conts_pos_vecs.shape[-1])
# Out:
# /tmp/ipykernel_19835/384431199.py:1: FutureWarning: The default argument for metric will be removed in future version of Annoy. Please pass metric='angular' explicitly.
#   train0_tree = AnnoyIndex(conts_neg_vecs.shape[-1])
# /tmp/ipykernel_19835/384431199.py:2: FutureWarning: The default argument for metric will be removed in future version of Annoy. Please pass metric='angular' explicitly.
#   train1_tree = AnnoyIndex(conts_pos_vecs.shape[-1])

# %%
# We have randomly selected training samples to control the memory usage
neg_idxs = np.random.choice(conts_neg_vecs.shape[0], size=50000, replace=False)
pos_idxs = np.random.choice(conts_pos_vecs.shape[0], size=50000, replace=False)

# %%
#for i in trange(conts_neg_vecs.shape[0]):
for i in trange(len(neg_idxs)):
    np_array = conts_neg_vecs[neg_idxs[i]].toarray()[0]
    train0_tree.add_item(i,np_array)
# Out:
# 100%|██████████| 50000/50000 [00:40<00:00, 1227.32it/s]

# %%
model_dir = "/home/jack/Desktop/NN/clean/models/"

train0_tree.build(50)
train0_tree.save(model_dir+'tfidf_train0.ann')
# Out:
# True

# %%
ref1_con[0:3], " ".join(attrs_neg[neg_idxs[0]])
# Out:
# (["it ' s yet they you feel at home .",
#   'i will be going back and this place !',
#   'the drinks were and a pour .'],
#  'can ability decided')

# %%
with open(data_dir+"/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/tfidf/reference_1.txt", "w") as out_fp:
    for i in range(conts_from_pos_ref_vecs.shape[0]):
        x = conts_from_pos_ref_vecs[i].toarray()[0]
        inx,dis = train0_tree.get_nns_by_vector(x, 1, include_distances=True)
        ref_sen = ref1_con[i]
        #ref_sen = processed_ref0[i].replace("<POS>","").replace("<NEG>","").replace("<CON_START>","").replace("<START>","")
        #print(dis,"\t",ref0_org[i], "\t" ,train1_data[inx[0]], train1_attr[inx[0]])
        out_str = "<ATTR_WORDS> " + " ".join(attrs_neg[neg_idxs[inx[0]]]) + " <CON_START> " + ref_sen.strip() + " <START>" + "\n"
        print(out_str)
        out_fp.write(out_str)
# Out:
# <ATTR_WORDS> dining uncomfortable <CON_START> it ' s yet they you feel at home . <START>
#
# <ATTR_WORDS> urge tell person <CON_START> i will be going back and this place ! <START>
#
# <ATTR_WORDS> wrong <CON_START> the drinks were and a pour . <START>
#
# <ATTR_WORDS> dog 's tests negative <CON_START> my husband got a ruben , he it . <START>
#
# <ATTR_WORDS> staff bar falling <CON_START> i up for their email and a coupon . <START>
#
# <ATTR_WORDS> cold killing <CON_START> i ' d giving them a try . <START>
#
# <ATTR_WORDS> home depot <CON_START> i e & m painting . <START>
#
# <ATTR_WORDS> no pregnant 's screw <CON_START> a experience and we will go again . <START>
#
# <ATTR_WORDS> high low <CON_START> drinks , and company . <START>
#
# <ATTR_WORDS> impressed dish <CON_START> i got my band back on now ! <START>
#
# <ATTR_WORDS> reminds me 's farm <CON_START> i was nervous and she made me feel so and . <START>
#
# <ATTR_WORDS> no nothing <CON_START> food recommendations steak and tuna were both . <START>
#
# <ATTR_WORDS> do n't good reviews <CON_START> everything is and so ! <START>
#
# <ATTR_WORDS> refused kept hanging <CON_START> the biscuits and gravy were . <START>
#
# <ATTR_WORDS> edit _num_ week died <CON_START> i to come back next year ! <START>
#
# <ATTR_WORDS> party _num_ <CON_START> they were so helpful , , and priced . <START>
#
# <ATTR_WORDS> customer lacking <CON_START> i pei wei . <START>
#
# <ATTR_WORDS> garage worked wall <CON_START> folks , bagels , tasty cream cheese . <START>
#
# <ATTR_WORDS> _num_ guests showed <CON_START> you ' ll see once you there . <START>
#
# <ATTR_WORDS> purchased new car _num_ _num_ <CON_START> everyone that i spoke with was very and . <START>
#
# <ATTR_WORDS> went chicken very <CON_START> the of sushi rolls for a eating . <START>
#
# <ATTR_WORDS> last step <CON_START> and every experience has a one . <START>
#
# <ATTR_WORDS> dentist saw zombie <CON_START> steve was and exactly the unit to fit in our space . <START>
#
# <ATTR_WORDS> terrible horrible <CON_START> this golf is one of the in my opinion . <START>
#
# <ATTR_WORDS> worse purchased <CON_START> dentist and staff ! <START>
#
# <ATTR_WORDS> 's hard mess <CON_START> portions are very and food is flavorful . <START>
#
# <ATTR_WORDS> 's been week n't <CON_START> always , fat , and . <START>
#
# <ATTR_WORDS> 's cheap carpet <CON_START> these two women are . <START>
#
# <ATTR_WORDS> trouble ... do n't shop <CON_START> the most , of course , is the . <START>
#
# <ATTR_WORDS> told me high <CON_START> we were both so . <START>
#
# <ATTR_WORDS> service crappy <CON_START> very brunch , was with selection and . <START>
#
# <ATTR_WORDS> sorry excuse `` '' <CON_START> the menu is very , , and tasty . <START>
#
# <ATTR_WORDS> went friday <CON_START> she was on as they were . <START>
#
# <ATTR_WORDS> no style <CON_START> i this place , the service is always ! <START>
#
# <ATTR_WORDS> got machine <CON_START> to shop for gift ! <START>
#
# <ATTR_WORDS> courtyard room <CON_START> a stop if you want things at a . <START>
#
# <ATTR_WORDS> no <CON_START> the atmosphere was and the staff you well . <START>
#
# <ATTR_WORDS> cheap full <CON_START> their line is so much than petsmart ! <START>
#
# <ATTR_WORDS> cooks rare <CON_START> this is a place where the customer first and is treated . <START>
#
# <ATTR_WORDS> manager sales showed <CON_START> i also their convenient off of scottsdale road . <START>
#
# <ATTR_WORDS> appears safety guest <CON_START> their pizza is the i have ever had as well as their ! <START>
#
# <ATTR_WORDS> just over-priced trying trendy <CON_START> i ' m so and will go back for future . <START>
#
# <ATTR_WORDS> stuck head running <CON_START> compared to every other thai place . <START>
#
# <ATTR_WORDS> quality does n't price <CON_START> she did the most . <START>
#
# <ATTR_WORDS> returning <CON_START> really the range . <START>
#
# <ATTR_WORDS> want pile meal <CON_START> they have a and a very knowledgeable staff . <START>
#
# <ATTR_WORDS> mess <CON_START> a to keep in mind . <START>
#
# <ATTR_WORDS> lacked personality <CON_START> place to hang out , a and a few brews ! <START>
#
# <ATTR_WORDS> honey chicken crunchy <CON_START> the lunch and dinner items are as well . <START>
#
# <ATTR_WORDS> left wrote appropriate _num_ <CON_START> charlie was and professional . <START>
#
# <ATTR_WORDS> needs smells bad <CON_START> the calzones are awesome and the lunch they have is . <START>
#
# <ATTR_WORDS> _num_ <CON_START> i will return often ! <START>
#
# <ATTR_WORDS> first brought _num_ _num_ people <CON_START> they have soups everyday . <START>
#
# <ATTR_WORDS> pathetic <CON_START> people , prompt service and clearly . <START>
#
# <ATTR_WORDS> unfortunately lackluster <CON_START> produce is very priced and selection of produce . <START>
#
# <ATTR_WORDS> okay need off <CON_START> the food here is . <START>
#
# <ATTR_WORDS> walked seated <CON_START> time i came in , i i just wanted something . <START>
#
# <ATTR_WORDS> why eateries <CON_START> a choice if going to a performing arts center . <START>
#
# <ATTR_WORDS> 'm torn <CON_START> this has been sushi and sashimi for years . <START>
#
# <ATTR_WORDS> not installed units _num_ <CON_START> even in summer , they have . <START>
#
# <ATTR_WORDS> leaves desired <CON_START> you will be by all of their advise , and knowledge ! <START>
#
# <ATTR_WORDS> nothing write <CON_START> i spent time with my buds and some wine and food . <START>
#
# <ATTR_WORDS> seat _num_ minutes open <CON_START> we with a group of and all had a time . <START>
#
# <ATTR_WORDS> imagine poured hours <CON_START> the service has been . <START>
#
# <ATTR_WORDS> good wings <CON_START> for making our night an to remember . <START>
#
# <ATTR_WORDS> skip <CON_START> i had a spanish omelet was and . <START>
#
# <ATTR_WORDS> remained dirty <CON_START> they have the massage chairs and each manicure station is . <START>
#
# <ATTR_WORDS> poor <CON_START> the wait staff is extremely and ! <START>
#
# <ATTR_WORDS> not unfortunately <CON_START> also , the is ! <START>
#
# <ATTR_WORDS> unfortunately _num_ faster <CON_START> the color that she on my girlfriend ' s hair . <START>
#
# <ATTR_WORDS> return <CON_START> it is and the staff is always . <START>
#
# <ATTR_WORDS> sent pulled cold <CON_START> friendly and welcoming with a atmosphere and food . <START>
#
# <ATTR_WORDS> utterly <CON_START> the chicken chimi i had was ! <START>
#
# <ATTR_WORDS> horrible experiences 'll <CON_START> it is also to at the bar . <START>
#
# <ATTR_WORDS> n't interesting <CON_START> the is to die for . <START>
#
# <ATTR_WORDS> 'd rather go bar <CON_START> the mexican in the phoenix area . <START>
#
# <ATTR_WORDS> hotels provide <CON_START> they are , and attentive to our needs . <START>
#
# <ATTR_WORDS> no seasoning not <CON_START> their lunch is a value ! <START>
#
# <ATTR_WORDS> quite expensive gyms <CON_START> our experience with this was . <START>
#
# <ATTR_WORDS> someone me go <CON_START> the staff is and location is in the of old town ! <START>
#
# <ATTR_WORDS> comes back says _num_ _num_ <CON_START> you have to outside to get the experience from this . <START>
#
# <ATTR_WORDS> strong hot <CON_START> the food is and plentiful . <START>
#
# <ATTR_WORDS> months garage issues <CON_START> and the fettuccine is scrumptious ! <START>
#
# <ATTR_WORDS> 's staple stop grocery <CON_START> we our truck of at this two weeks ago . <START>
#
# <ATTR_WORDS> thing not here <CON_START> this the last little to what was already an place . <START>
#
# <ATTR_WORDS> beer $ _num_ <CON_START> prices are a tad but it . <START>
#
# <ATTR_WORDS> walked ignored <CON_START> the therapist is also . <START>
#
# <ATTR_WORDS> prices unreasonable <CON_START> came with my . <START>
#
# <ATTR_WORDS> took left <CON_START> the , i will go in half with you . <START>
#
# <ATTR_WORDS> offered something others <CON_START> the escargot was , and seasoned . <START>
#
# <ATTR_WORDS> did n't finish <CON_START> brittany me a very haircut and me completely . <START>
#
# <ATTR_WORDS> filed police hopes <CON_START> this resort has been in scottsdale forever and it service . <START>
#
# <ATTR_WORDS> shrimp worst 've <CON_START> also the wontons along with the plum sauce . <START>
#
# <ATTR_WORDS> ca n't <CON_START> i have so many at a of a price ! <START>
#
# <ATTR_WORDS> seemed pretty me <CON_START> all place to a drink or two . <START>
#
# <ATTR_WORDS> frustrated n't <CON_START> the flourless was one of the desserts i ' ve ever had . <START>
#
# <ATTR_WORDS> store needs <CON_START> scenery and staff . <START>
#
# <ATTR_WORDS> horrible <CON_START> wine list at 2x rather than the more 3x . <START>
#
# <ATTR_WORDS> don promised call <CON_START> we our on the river and n ' t wait to go back ! <START>
#
# <ATTR_WORDS> no n't place craving <CON_START> if you ' re and are into this is the for you . <START>
#
# <ATTR_WORDS> old fresh <CON_START> i their design collection . <START>
#
# <ATTR_WORDS> no me stay <CON_START> i their juices as well . <START>
#
# <ATTR_WORDS> absolutely recommend <CON_START> a do if you have time in the phoenix area . <START>
#
# <ATTR_WORDS> messy sloppy <CON_START> oj and jeremy did a ! <START>
#
# <ATTR_WORDS> wasted last <CON_START> , alignment , and more . <START>
#
# <ATTR_WORDS> train me simply <CON_START> it was very to ! <START>
#
# <ATTR_WORDS> good atmosphere ok <CON_START> staff : very and . <START>
#
# <ATTR_WORDS> charging horrible eating <CON_START> the afternoon - at the phoenician . <START>
#
# <ATTR_WORDS> good disappointment <CON_START> their enchilada sauce this dish . <START>
#
# <ATTR_WORDS> so am open 8:30 <CON_START> decoration and service . <START>
#
# <ATTR_WORDS> staff lovely just n't <CON_START> very with service and of work . <START>
#
# <ATTR_WORDS> _num_ <CON_START> one of my to go for a steak . <START>
#
# <ATTR_WORDS> says no corporate <CON_START> this place is yummy ! <START>
#
# <ATTR_WORDS> skip <CON_START> they are with decor . <START>
#
# <ATTR_WORDS> rude throw <CON_START> this is my to place . <START>
#
# <ATTR_WORDS> rip-off <CON_START> the people at sonora were to me . <START>
#
# <ATTR_WORDS> did n't honor discount <CON_START> the patio is a place to at 7pm . <START>
#
# <ATTR_WORDS> n't chew tough <CON_START> it was well it . <START>
#
# <ATTR_WORDS> fell love <CON_START> sushi kee , how i thee ! <START>
#
# <ATTR_WORDS> am asians <CON_START> she kept our drinks and gave us food recommendations . <START>
#
# <ATTR_WORDS> ladies room n't bad <CON_START> the burgers , i had the jalapeo burger it was tasty . <START>
#
# <ATTR_WORDS> no 'm <CON_START> kebab dishes and service . <START>
#
# <ATTR_WORDS> nightmare <CON_START> i a bagel breakfast sandwich and it was ! <START>
#
# <ATTR_WORDS> charge _num_ fee truck <CON_START> the service was and the staff was very . <START>
#
# <ATTR_WORDS> anyway definitely wo n't ... <CON_START> pool tables and drinks this a night out ! <START>
#
# <ATTR_WORDS> awful <CON_START> the eggs are , the side of fruit always . <START>
#
# <ATTR_WORDS> never always myself <CON_START> pricing is both and . <START>
#
# <ATTR_WORDS> can smell <CON_START> these guys are top notch , and very . <START>
#
# <ATTR_WORDS> sour served fairly <CON_START> they me like i was at home and their an family ! <START>
#
# <ATTR_WORDS> went location <CON_START> sometimes it ' s a , other times is more complicated . <START>
#
# <ATTR_WORDS> worst experiences eatery <CON_START> giving an for customer service . <START>
#
# <ATTR_WORDS> mistake <CON_START> it ' s a big bowl of . <START>
#
# <ATTR_WORDS> aside unimpressed <CON_START> one of my chinese place to ! <START>
#
# <ATTR_WORDS> slow ridiculous <CON_START> after the river too . <START>
#
# <ATTR_WORDS> worst pizza <CON_START> food , a plate a long way . <START>
#
# <ATTR_WORDS> server patient party _num_ <CON_START> the was and would gladly go back . <START>
#
# <ATTR_WORDS> went doggie heaven <CON_START> i the pork tacos . <START>
#
# <ATTR_WORDS> no busy <CON_START> everyone is and knowledgeable . <START>
#
# <ATTR_WORDS> recommend here <CON_START> but thoughts from anyone i have their way ! <START>
#
# <ATTR_WORDS> very <CON_START> the dolly a lot . <START>
#
# <ATTR_WORDS> so food buca _num_ <CON_START> jennifer is and she really makes care affordable . <START>
#
# <ATTR_WORDS> plenty rental <CON_START> this is a and i am excited to have found it . <START>
#
# <ATTR_WORDS> feel 've cheated <CON_START> this is darn pizza ! <START>
#
# <ATTR_WORDS> ordered food _num_ minutes <CON_START> everything we ' ve ever has been tasting . <START>
#
# <ATTR_WORDS> 's almost chicken <CON_START> it is the most in the valley . <START>
#
# <ATTR_WORDS> _num_ <CON_START> staff and food . <START>
#
# <ATTR_WORDS> really deserved neglected <CON_START> the mole sauce , chips are and thick . <START>
#
# <ATTR_WORDS> conclusion waste <CON_START> here , you will it . <START>
#
# <ATTR_WORDS> fair ok <CON_START> i the ribs more than the . <START>
#
# <ATTR_WORDS> nasty <CON_START> staff and the ride were . <START>
#
# <ATTR_WORDS> should n't guarantee absolutely <CON_START> also , we were last time we our dogs for shots . <START>
#
# <ATTR_WORDS> charge considerably <CON_START> i the drunken dragon noodles ( for you ! ) <START>
#
# <ATTR_WORDS> worst <CON_START> for a chain this place is ! <START>
#
# <ATTR_WORDS> worst customer <CON_START> this place me of ! <START>
#
# <ATTR_WORDS> place rip <CON_START> one of my in scottsdale . <START>
#
# <ATTR_WORDS> just requested <CON_START> i will here again ! <START>
#
# <ATTR_WORDS> easily rudest individuals <CON_START> in for lunch , wine list , service . <START>
#
# <ATTR_WORDS> mmm not happy <CON_START> i that this is the place in the - family circus . <START>
#
# <ATTR_WORDS> just awkward <CON_START> it is an international . <START>
#
# <ATTR_WORDS> told 've bad process <CON_START> it was so and quaint ! <START>
#
# <ATTR_WORDS> love 's food awful <CON_START> i the outside seating and the reverse hour is affordable . <START>
#
# <ATTR_WORDS> do n't know begin ... <CON_START> the is at the sugar bowl is . <START>
#
# <ATTR_WORDS> bf really upset n't <CON_START> with that being said , i the . <START>
#
# <ATTR_WORDS> skip <CON_START> food , decor ! <START>
#
# <ATTR_WORDS> typical courtyard decorated <CON_START> the food is always . <START>
#
# <ATTR_WORDS> low authentic <CON_START> you can come in , spend any amount of and something . <START>
#
# <ATTR_WORDS> gross <CON_START> all of the that i had was . <START>
#
# <ATTR_WORDS> people should n't pay <CON_START> so far , service . <START>
#
# <ATTR_WORDS> negative stars <CON_START> is a seriously guy ! <START>
#
# <ATTR_WORDS> england prepared disappointed <CON_START> we ate here yesterday for hour and it was . <START>
#
# <ATTR_WORDS> place too <CON_START> that ' s a in a business . <START>
#
# <ATTR_WORDS> do hire <CON_START> it ' s food . <START>
#
# <ATTR_WORDS> feel should <CON_START> club layout the course was in to above average shape . <START>
#
# <ATTR_WORDS> did taste <CON_START> we ' be back ! <START>
#
# <ATTR_WORDS> living 'm spoiled <CON_START> the meatloaf when they have it ) is . <START>
#
# <ATTR_WORDS> supposed ground chicken <CON_START> here is also so ! <START>
#
# <ATTR_WORDS> walked store <CON_START> you , i will be back ! <START>
#
# <ATTR_WORDS> n't friendly helpful dish <CON_START> i their flavored coffee . <START>
#
# <ATTR_WORDS> waiting hour no <CON_START> the staff made us feel very and . <START>
#
# <ATTR_WORDS> _num_ no customers <CON_START> the food is and from what i can tell is . <START>
#
# <ATTR_WORDS> confusion taken table <CON_START> i would of town scottsdale to everyone . <START>
#
# <ATTR_WORDS> _num_ thumbs <CON_START> my father has decided to my engagement this xmas . <START>
#
# <ATTR_WORDS> found does <CON_START> the deals in the are on these racks . <START>
#
# <ATTR_WORDS> bad food poisoning <CON_START> the guys here are sooo and helpful . <START>
#
# <ATTR_WORDS> fail <CON_START> will all my back for sure ! <START>
#
# <ATTR_WORDS> 's not bank <CON_START> the was although next time i will ask for a one . <START>
#
# <ATTR_WORDS> do n't waste <CON_START> place to have some fresh and donuts . <START>
#
# <ATTR_WORDS> open half <CON_START> came to get breakfast and that was the yet . <START>
#
# <ATTR_WORDS> marked too high <CON_START> they have an of combos to choose from . <START>
#
# <ATTR_WORDS> professionalism ridiculous <CON_START> they were , not too but and light . <START>
#
# <ATTR_WORDS> hate furious <CON_START> of salads and pasta items in the deli . <START>
#
# <ATTR_WORDS> wo n't <CON_START> overall really food and service . <START>
#
# <ATTR_WORDS> parking _num_ daily wifi _num_ <CON_START> everyone was extremely and . <START>
#
# <ATTR_WORDS> no spare <CON_START> i got the tamale . <START>
#
# <ATTR_WORDS> $ _num_ hair n't <CON_START> also matt was and helpful . <START>
#
# <ATTR_WORDS> hot made <CON_START> my plate , amount of food . <START>
#
# <ATTR_WORDS> unique visit <CON_START> and again , the food is ! <START>
#
# <ATTR_WORDS> tonight am disappointed <CON_START> but it is the wait . <START>
#
# <ATTR_WORDS> unfortunate love <CON_START> grimaldi ' s is the most pizza in arizona . <START>
#
# <ATTR_WORDS> country unfortunate <CON_START> but service every time i come here . <START>
#
# <ATTR_WORDS> prices high <CON_START> by the staff . <START>
#
# <ATTR_WORDS> finished ghost <CON_START> i also dessert here when i have a tooth . <START>
#
# <ATTR_WORDS> disappeared back <CON_START> i have a dish here to eat . <START>
#
# <ATTR_WORDS> not <CON_START> this is by my pizza . <START>
#
# <ATTR_WORDS> insisted <CON_START> the bartender was and to help us especially with the crowd . <START>
#
# <ATTR_WORDS> ordered oysters <CON_START> service was as they to on our table . <START>
#
# <ATTR_WORDS> apologies <CON_START> you ladies for being ! <START>
#
# <ATTR_WORDS> whole weird <CON_START> and service , these guys know their stuff . <START>
#
# <ATTR_WORDS> negative stars <CON_START> a to visit . <START>
#
# <ATTR_WORDS> _num_ <CON_START> for me to and work and have a breakfast ! <START>
#
# <ATTR_WORDS> not inexpensive <CON_START> and tastings at least once a month . <START>
#
# <ATTR_WORDS> intended visiting right <CON_START> our waitress was the , accommodating . <START>
#
# <ATTR_WORDS> $ _num_ ... crappy cooked <CON_START> while the menu is , what it offer is first - rate . <START>
#
# <ATTR_WORDS> ca n't afford hire <CON_START> not cheap but you get here . <START>
#
# <ATTR_WORDS> disappointed <CON_START> menu , prices , service - for both dinner and breakfast ! <START>
#
# <ATTR_WORDS> wife stopped home <CON_START> , prices on wings on tuesdays . <START>
#
# <ATTR_WORDS> eat <CON_START> the place was busy but the was ! <START>
#
# <ATTR_WORDS> _num_ refuse _num_ p.m. check-out diamond members <CON_START> though i to go and the food was just as . <START>
#
# <ATTR_WORDS> happy <CON_START> this place has some . <START>
#
# <ATTR_WORDS> hours essentially chinese <CON_START> the two men up front are so . <START>
#
# <ATTR_WORDS> businesses ca n't pay <CON_START> the salsa is , the fish notch , the drinks just . <START>
#
# <ATTR_WORDS> king bed $ _num_ <CON_START> i this place so much i have inquired about a franchise . <START>
#
# <ATTR_WORDS> bland <CON_START> and the seafood enchiladas were ! <START>
#
# <ATTR_WORDS> hell <CON_START> the bread is made and i could probably it all day . <START>
#
# <ATTR_WORDS> yet could n't communicate <CON_START> the portions were , the food came out hot , and . <START>
#
# <ATTR_WORDS> order n't complete ask <CON_START> a bit on the side but the food up for it . <START>
#
# <ATTR_WORDS> no <CON_START> ambiance and setting were . <START>
#
# <ATTR_WORDS> gross tasted <CON_START> pizza was to and fast ! <START>
#
# <ATTR_WORDS> good wash should <CON_START> our bartender erik care of my fiance and i . <START>
#
# <ATTR_WORDS> owner nasty <CON_START> everyone who works there is always so and . <START>
#
# <ATTR_WORDS> should horrible <CON_START> i the cornbread appetizer . <START>
#
# <ATTR_WORDS> cheap <CON_START> the huevos rancheros and it was ! <START>
#
# <ATTR_WORDS> maybe should <CON_START> the customer service in this is ! <START>
#
# <ATTR_WORDS> took _num_ months problem <CON_START> the firecracker shrimp and duck is also a . <START>
#
# <ATTR_WORDS> here maybe try <CON_START> service was to ! <START>
#
# <ATTR_WORDS> n't feeling here <CON_START> the service is and attentive . <START>
#
# <ATTR_WORDS> why bother <CON_START> food and service ! <START>
#
# <ATTR_WORDS> nothing offered not <CON_START> this place still . <START>
#
# <ATTR_WORDS> _num_ minutes order showed <CON_START> biscuits and gravy are a breakfast too . <START>
#
# <ATTR_WORDS> 'm worst service <CON_START> a experience there with the owner and the rest of the . <START>
#
# <ATTR_WORDS> covered dirty <CON_START> well searching out this . <START>
#
# <ATTR_WORDS> dog 's tests negative <CON_START> my husband and i our 3rd here . <START>
#
# <ATTR_WORDS> # _num_ beef <CON_START> this is a golf course that is away it is in condition . <START>
#
# <ATTR_WORDS> 're confused does n't <CON_START> plus my wine were delish ! <START>
#
# <ATTR_WORDS> moved exam room <CON_START> pricy but the pies are ! <START>
#
# <ATTR_WORDS> _num_ room entire <CON_START> the bbq salmon was . <START>
#
# <ATTR_WORDS> left _num_ minutes 7:30 <CON_START> the of my thanksgiving dinner by far was cakes pecan pie . <START>
#
# <ATTR_WORDS> geek rip horrible <CON_START> even their veggies are . <START>
#
# <ATTR_WORDS> huge waste speedy <CON_START> this is a go if you ' re a to be ! <START>
#
# <ATTR_WORDS> n't add reviews just <CON_START> combination of flavors , very . <START>
#
# <ATTR_WORDS> _num_ <CON_START> mustard beef are a . <START>
#
# <ATTR_WORDS> sad faces <CON_START> i had the burger once and it was and very ! <START>
#
# <ATTR_WORDS> gave rewards self <CON_START> i the as followed . <START>
#
# <ATTR_WORDS> did not star <CON_START> the tzatziki sauce with everything you get ! <START>
#
# <ATTR_WORDS> chicken poorly <CON_START> my meal was very and . <START>
#
# <ATTR_WORDS> too bad n't _num_ stars <CON_START> anything on the menu and you will be glad you in ! <START>
#
# <ATTR_WORDS> good wash should <CON_START> bartender a dirty martini ! <START>
#
# <ATTR_WORDS> informed me carrots <CON_START> omg carlsbad is ! <START>
#
# <ATTR_WORDS> tried 's trio disappointing <CON_START> other than that , it ' ! <START>
#
# <ATTR_WORDS> hungry hungry <CON_START> i had on my recent trip to scottsdale . <START>
#
# <ATTR_WORDS> rude careless <CON_START> extremely attentive and a person . <START>
#
# <ATTR_WORDS> someone mess chick <CON_START> it ' s basic , , mexican food that is homemade and . <START>
#
# <ATTR_WORDS> stale cold <CON_START> food is very and ! <START>
#
# <ATTR_WORDS> worst customer 've <CON_START> the was , the servers were and on top of things . <START>
#
# <ATTR_WORDS> plain white mess <CON_START> tacos were pretty . <START>
#
# <ATTR_WORDS> tried place _num_ <CON_START> down the dentist office in the east valley ! <START>
#
# <ATTR_WORDS> fooled find doctor <CON_START> they are all very . <START>
#
# <ATTR_WORDS> feel buying fresh <CON_START> he always and is so when i pick him up ! <START>
#
# <ATTR_WORDS> 's busy <CON_START> i italian and i here often . <START>
#
# <ATTR_WORDS> service <CON_START> of food is . <START>
#
# <ATTR_WORDS> im ok ridiculous <CON_START> the service was and my hostess was very and helpful . <START>
#
# <ATTR_WORDS> sent me collections <CON_START> the bar in town . <START>
#
# <ATTR_WORDS> food damn cold <CON_START> they are doing a job . <START>
#
# <ATTR_WORDS> barely <CON_START> russ was a qualified . <START>
#
# <ATTR_WORDS> watery little <CON_START> when we get into , this is the we come ! <START>
#
# <ATTR_WORDS> wants smell piss <CON_START> you fiesta , lunch with you is always . <START>
#
# <ATTR_WORDS> _num_ _num_ incorrect missing <CON_START> they also are the in the area . <START>
#
# <ATTR_WORDS> do n't waste <CON_START> chile chimis are . <START>
#
# <ATTR_WORDS> may go <CON_START> for the repair . <START>
#
# <ATTR_WORDS> fast friendly <CON_START> atmosphere , food . <START>
#
# <ATTR_WORDS> but exam <CON_START> had dinner last night and it was . <START>
#
# <ATTR_WORDS> did n't try 'm tiny <CON_START> the marinara sauce is . <START>
#
# <ATTR_WORDS> oyster oyster <CON_START> they are incredibly and accommodating . <START>
#
# <ATTR_WORDS> sorry wo n't mall <CON_START> the service was notch and the food was a bit of . <START>
#
# <ATTR_WORDS> not store over-priced not <CON_START> it can be pricey , but it is it . <START>
#
# <ATTR_WORDS> gone _num_ _num_ processed <CON_START> staff , food , prices . <START>
#
# <ATTR_WORDS> still barely <CON_START> n prices were ! <START>
#
# <ATTR_WORDS> recommend place <CON_START> every themselves and there was nothing but from our entire group . <START>
#
# <ATTR_WORDS> am hurting did n't <CON_START> persian not to mention service . <START>
#
# <ATTR_WORDS> do n't first appointment 's <CON_START> you for a evening ! <START>
#
# <ATTR_WORDS> visited location <CON_START> my daughter care . <START>
#
# <ATTR_WORDS> review office manager <CON_START> , priced and they the phone when called promptly . <START>
#
# <ATTR_WORDS> worth <CON_START> they were very and apologetic . <START>
#
# <ATTR_WORDS> feels wrong <CON_START> the list was the part . <START>
#
# <ATTR_WORDS> red same charges <CON_START> it ' a much option than the scene . <START>
#
# <ATTR_WORDS> take `` '' sign n't sell <CON_START> i ordered the carne asada steak and it was ! <START>
#
# <ATTR_WORDS> needless say wo n't <CON_START> that comes with the though . <START>
#
# <ATTR_WORDS> gross <CON_START> place to drink beer . <START>
#
# <ATTR_WORDS> no <CON_START> it is very very oriented and we that too ! <START>
#
# <ATTR_WORDS> really worst <CON_START> even the sides were . <START>
#
# <ATTR_WORDS> chicken wings stale n't <CON_START> she did an job on my color and my ! <START>
#
# <ATTR_WORDS> me walked me <CON_START> the is a hoot and the is very accommodating . <START>
#
# <ATTR_WORDS> exciting not atmosphere <CON_START> will come back time i ' m in . <START>
#
# <ATTR_WORDS> so got groupon _num_ <CON_START> he was both and courteous . <START>
#
# <ATTR_WORDS> trouble ... do n't shop <CON_START> this course is one of the in the . <START>
#
# <ATTR_WORDS> finishing figured pitcher <CON_START> if you ' re into that sort of by and it out ! <START>
#
# <ATTR_WORDS> went cooks disappointed <CON_START> i coming for lunch to get the . <START>
#
# <ATTR_WORDS> added salt lacking <CON_START> it is a half a from phoenix area . <START>
#
# <ATTR_WORDS> horrible orders incorrect <CON_START> the of this place ! <START>
#
# <ATTR_WORDS> can _num_ stars <CON_START> the staff are all and on of there jobs . <START>
#
# <ATTR_WORDS> ended throwing eating <CON_START> bread was also ! <START>
#
# <ATTR_WORDS> lazy @ <CON_START> food and priced . <START>
#
# <ATTR_WORDS> went last <CON_START> they the rock climb . <START>
#
# <ATTR_WORDS> place charge <CON_START> tasty and a much deal than the sub joints . <START>
#
# <ATTR_WORDS> _num_ stars just event <CON_START> by far the i have ever had in a auto shop . <START>
#
# <ATTR_WORDS> strike _num_ <CON_START> so with my decision to go . <START>
#
# <ATTR_WORDS> out items etc <CON_START> it was pretty inexpensive and they music videos . <START>
#
# <ATTR_WORDS> looked tasted ... <CON_START> throwback ; ice cream parlor . <START>
#
# <ATTR_WORDS> sucked <CON_START> at the bar and the small plates . <START>
#
# <ATTR_WORDS> stared idiot <CON_START> the grounds are very . <START>
#
# <ATTR_WORDS> state sample <CON_START> i returned from a stay at the camelback . <START>
#
# <ATTR_WORDS> rude meat <CON_START> a , and an enchilada . <START>
#
# <ATTR_WORDS> saved $ _num_ <CON_START> they go and beyond ! <START>
#
# <ATTR_WORDS> no no <CON_START> i ' ve been several times and every time has . <START>
#
# <ATTR_WORDS> just guess <CON_START> the news that my had made the visit even better . <START>
#
# <ATTR_WORDS> anyway <CON_START> it is a little place to relax and get . <START>
#
# <ATTR_WORDS> why good <CON_START> we & american service to everyone we know . <START>
#
# <ATTR_WORDS> worst ... horrible <CON_START> the are very and really , not pushy at all . <START>
#
# <ATTR_WORDS> worst place 've <CON_START> its and people are here . <START>
#
# <ATTR_WORDS> bar rude <CON_START> the most white pizza since living here in az . <START>
#
# <ATTR_WORDS> nothing offered not <CON_START> after several other gyro place still has the sauce . <START>
#
# <ATTR_WORDS> worst <CON_START> service was and was even better . <START>
#
# <ATTR_WORDS> bathrooms should <CON_START> suzanne and her staff were ! <START>
#
# <ATTR_WORDS> cheese salt <CON_START> all in all ! <START>
#
# <ATTR_WORDS> excuse horrible <CON_START> fast , and service . <START>
#
# <ATTR_WORDS> used vehicle <CON_START> food , service , their catering not be beat . <START>
#
# <ATTR_WORDS> manager rude <CON_START> i had the pork here ever ! <START>
#
# <ATTR_WORDS> nurses ca n't <CON_START> you can tell how the are . <START>
#
# <ATTR_WORDS> favorite flying <CON_START> i ' ll go back again . <START>
#
# <ATTR_WORDS> total oil _num_ hours _num_ <CON_START> coupon or not , this place is and a very value . <START>
#
# <ATTR_WORDS> worth <CON_START> this is the seafood in town . <START>
#
# <ATTR_WORDS> $ _num_ supposed <CON_START> up the service ! <START>
#
# <ATTR_WORDS> worst take <CON_START> every time i crave mexican , i ! <START>
#
# <ATTR_WORDS> tour n't bad <CON_START> my dr pepper ribs were and very . <START>
#
# <ATTR_WORDS> so equipment does n't <CON_START> everyone is always and helpful . <START>
#
# <ATTR_WORDS> took spicy tuna <CON_START> it ' s , cooked , and ! <START>
#
# <ATTR_WORDS> just poor <CON_START> all around the world and indian well . <START>
#
# <ATTR_WORDS> do n't waste money <CON_START> location for weekend volleyball tournaments ! <START>
#
# <ATTR_WORDS> food never <CON_START> , to name a few we have seen . <START>
#
# <ATTR_WORDS> terrible rude <CON_START> taking my family here always the sea . <START>
#
# <ATTR_WORDS> none took <CON_START> owners and staff and food ! <START>
#
# <ATTR_WORDS> not <CON_START> they will even to the ! <START>
#
# <ATTR_WORDS> maybe bad <CON_START> ron is still the . <START>
#
# <ATTR_WORDS> spoke barrier <CON_START> family little and i mean little restaurant with food . <START>
#
# <ATTR_WORDS> not upscale <CON_START> of meats and cheeses . <START>
#
# <ATTR_WORDS> did not star <CON_START> had the normal gyro sandwich with their sauce . . . . <START>
#
# <ATTR_WORDS> food terrible <CON_START> i had probably one of the restaurant i ' ve ever had . <START>
#
# <ATTR_WORDS> but outdoor <CON_START> green tamales around . <START>
#
# <ATTR_WORDS> however zero stars <CON_START> everything they serve there is . <START>
#
# <ATTR_WORDS> `` '' room disgusting disappointing <CON_START> to watch the kitchen in hour . <START>
#
# <ATTR_WORDS> probably would n't health <CON_START> place was and kept , drinks were priced . <START>
#
# <ATTR_WORDS> using company <CON_START> the employees always me and my dog , which is . <START>
#
# <ATTR_WORDS> promised me massive <CON_START> we to come as a . <START>
#
# <ATTR_WORDS> liked horrible <CON_START> they also my which is hard to find . <START>
#
# <ATTR_WORDS> gave _num_ star n't <CON_START> , hospitable , knowledgeable , and . <START>
#
# <ATTR_WORDS> no <CON_START> it ' s in a part of scottsdale and was accommodating . <START>
#
# <ATTR_WORDS> should serve <CON_START> but it ' seeking out . <START>
#
# <ATTR_WORDS> let just saying <CON_START> staff , quick service and and simple food done right ! <START>
#
# <ATTR_WORDS> terribly <CON_START> prices and the associates there are all customer and helpful ! <START>
#
# <ATTR_WORDS> paying _num_ bad n't worth <CON_START> and i had my sugar bowl , the hat sundae ! <START>
#
# <ATTR_WORDS> cold bean <CON_START> prices , selection . <START>
#
# <ATTR_WORDS> bad <CON_START> very and service ! <START>
#
# <ATTR_WORDS> _num_ thousands im auto <CON_START> this is the store in the metro area . <START>
#
# <ATTR_WORDS> unfortunately downhill <CON_START> lunch specials and staff . <START>
#
# <ATTR_WORDS> not fan flour <CON_START> and have every last . <START>
#
# <ATTR_WORDS> walked store <CON_START> is always no matter what i order . <START>
#
# <ATTR_WORDS> recommend long lovers <CON_START> they were extremely and priced . <START>
#
# <ATTR_WORDS> took too slow <CON_START> selection of parts and accessories and prices . <START>
#
# <ATTR_WORDS> nothing write <CON_START> the food is here and very . <START>
#
# <ATTR_WORDS> expect wait 1-2 hours <CON_START> food , low prices , and an mexican cantina . <START>
#
# <ATTR_WORDS> scheduled cab bring <CON_START> this place offers , take out . <START>
#
# <ATTR_WORDS> story ... <CON_START> it ' s a whole experience and each time you go . <START>
#
# <ATTR_WORDS> ate no <CON_START> myself and / have been to them for years ! <START>
#
# <ATTR_WORDS> lack <CON_START> they ' ve some on the menu since my last visit . <START>
#
# <ATTR_WORDS> too bad <CON_START> they it out front for you and are very . <START>
#
# <ATTR_WORDS> am `` ghost '' <CON_START> place to go for with multiple tvs and a crowd . <START>
#
# <ATTR_WORDS> # _num_ beef <CON_START> all of my are returned in condition ! <START>
#
# <ATTR_WORDS> frustrated n't <CON_START> one of veal i ' ve ever had and prices . <START>
#
# <ATTR_WORDS> huge <CON_START> the food was , steak and hummus plate a . <START>
#
# <ATTR_WORDS> turn monthly <CON_START> as far as pizza this with the i ' ve ever eaten . <START>
#
# <ATTR_WORDS> people did not <CON_START> really service and . <START>
#
# <ATTR_WORDS> do n't 's horrible <CON_START> their sandwiches were tasty . <START>
#
# <ATTR_WORDS> stay here _num_ <CON_START> always a and atmosphere . <START>
#
# <ATTR_WORDS> good soup <CON_START> i ' a - through customer at this location . <START>
#
# <ATTR_WORDS> could n't save day <CON_START> it was ; i ' ve had anything like it ! <START>
#
# <ATTR_WORDS> missed <CON_START> something i will have again ! <START>
#
# <ATTR_WORDS> restaurant maybe _num_ people <CON_START> the california burrito was a burrito . <START>
#
# <ATTR_WORDS> dessert really <CON_START> the woman who me today was and knowledgeable . <START>
#
# <ATTR_WORDS> cheap brands high <CON_START> the service was , food , and the impeccable . <START>
#
# <ATTR_WORDS> did n't sold costumes <CON_START> the menu and the drinks . <START>
#
# <ATTR_WORDS> lose process <CON_START> pei wei has prices , service , and outdoor seating . <START>
#
# <ATTR_WORDS> bad place <CON_START> it was a experience ! <START>
#
# <ATTR_WORDS> thanks jerk <CON_START> his humor a routine visit . <START>
#
# <ATTR_WORDS> places out <CON_START> this place and will coming back . <START>
#
# <ATTR_WORDS> _num_ ounce vodka ridiculous <CON_START> we were sat away and every staff member was extremely and . <START>
#
# <ATTR_WORDS> horrible <CON_START> will go back and to friends . <START>
#
# <ATTR_WORDS> _num_ games <CON_START> their calzone is really ! <START>
#
# <ATTR_WORDS> generic <CON_START> the food is also . <START>
#
# <ATTR_WORDS> bottom barrel <CON_START> the were also tasted and the churros with ice cream was . <START>
#
# <ATTR_WORDS> live property hotel <CON_START> i the ahi tuna . <START>
#
# <ATTR_WORDS> no body <CON_START> she was so , and understanding . <START>
#
# <ATTR_WORDS> new asked <CON_START> , even the pizza is . <START>
#
# <ATTR_WORDS> principle did n't finish <CON_START> to and very flavorful . <START>
#
# <ATTR_WORDS> not good <CON_START> the crew was and accommodating . <START>
#
# <ATTR_WORDS> service slow <CON_START> the sushi here is and i the cucumber salad . <START>
#
# <ATTR_WORDS> disappointed <CON_START> if you are looking to out this is your place ! <START>
#
# <ATTR_WORDS> should n't one star <CON_START> she a color that looks with my skin , too . <START>
#
# <ATTR_WORDS> did n't children <CON_START> a place to watch ! <START>
#
# <ATTR_WORDS> always guests <CON_START> this little pizza , salad and pasta place in chandler is . <START>
#
# <ATTR_WORDS> rude too <CON_START> the in the alley behind it is too ! <START>
#
# <ATTR_WORDS> not event straw <CON_START> but being a tucson native this via my tastebuds . <START>
#
# <ATTR_WORDS> ca n't treat customers <CON_START> parmesan i have ever had . <START>
#
# <ATTR_WORDS> wandered someone tea <CON_START> customer service was there . <START>
#
# <ATTR_WORDS> honest n't place <CON_START> place to a game on tv and up w / people . <START>
#
# <ATTR_WORDS> am appalled lack <CON_START> most chinese food ! <START>
#
# <ATTR_WORDS> want place ca n't <CON_START> the and guacamole were too ! <START>
#
# <ATTR_WORDS> pay dressing side <CON_START> this place is when you can sit outside . <START>
#
# <ATTR_WORDS> does n't sense <CON_START> a little to back a few beers after a rough day . <START>
#
# <ATTR_WORDS> ordered large go <CON_START> i this place to others ! <START>
#
# <ATTR_WORDS> calm yelling <CON_START> the food was and the price of it was even better . <START>
#
# <ATTR_WORDS> worse speak salon <CON_START> i the waiter ' s of the veal carolina and it was ! <START>
#
# <ATTR_WORDS> rings tasted <CON_START> super deals and very staff . <START>
#
# <ATTR_WORDS> excuse <CON_START> their lasagna and its the ive ever had . <START>
#
# <ATTR_WORDS> gave me options _num_ <CON_START> this place is edgy and . <START>
#
# <ATTR_WORDS> me wrong <CON_START> place to see a show as every seat is a ! <START>
#
# <ATTR_WORDS> n't worse lies fear <CON_START> she was absolutely and i what she did ! <START>
#
# <ATTR_WORDS> pizza knots <CON_START> the hour here can be on occasion . <START>
#
# <ATTR_WORDS> comment stated <CON_START> busy but very service . <START>
#
# <ATTR_WORDS> ( ... am <CON_START> take out or in sushi ! <START>
#
# <ATTR_WORDS> not fan flour <CON_START> i have had a every time from start to . <START>
#
# <ATTR_WORDS> disappointed <CON_START> he is very and cares for his customers . <START>
#
# <ATTR_WORDS> horrible <CON_START> he has prices , how could you not go ? <START>
#
# <ATTR_WORDS> location open _num_ <CON_START> the staff are and on the ball . <START>
#
# <ATTR_WORDS> _num_ <CON_START> all had that grease that washed down with beers . <START>
#
# <ATTR_WORDS> did n't review off <CON_START> i was a walk in and got away ! <START>
#
# <ATTR_WORDS> no just <CON_START> if you in the bar they have the bartender in town . <START>
#
# <ATTR_WORDS> do n't maybe 's <CON_START> i highly this shop . <START>
#
# <ATTR_WORDS> tea tea same <CON_START> their staff is knowledgeable and . <START>
#
# <ATTR_WORDS> not value <CON_START> it is a , with to see and try . <START>
#
# <ATTR_WORDS> not interested <CON_START> they are , very helpful , and quick ! <START>
#
# <ATTR_WORDS> fish too crispy <CON_START> i got my car here and it looked ! <START>
#
# <ATTR_WORDS> no fabric <CON_START> dr . hall is so and . <START>
#
# <ATTR_WORDS> low <CON_START> i had to it up even , a portion . <START>
#
# <ATTR_WORDS> comfortable found <CON_START> the food all . <START>
#
# <ATTR_WORDS> why gave <CON_START> the menudo here is . <START>
#
# <ATTR_WORDS> visit last <CON_START> the mango fish was tasty . <START>
#
# <ATTR_WORDS> could n't eat <CON_START> now the , drinks , and desserts are . <START>
#
# <ATTR_WORDS> awful <CON_START> the carne burrito is ! <START>
#
# <ATTR_WORDS> probably worst 've been <CON_START> this is the date night . <START>
#
# <ATTR_WORDS>  <CON_START> selection of to play . <START>
#
# <ATTR_WORDS> inconsistent <CON_START> the grilled artichokes are ! <START>
#
# <ATTR_WORDS> portions small <CON_START> the adovada is but and the chocolate bread pudding is . <START>
#
# <ATTR_WORDS> could n't eat <CON_START> and inexpensive way to and relax your day . <START>
#
# <ATTR_WORDS> returning one <CON_START> i it and will be back ! <START>
#
# <ATTR_WORDS> no stars <CON_START> at bar that we reservations at next door . <START>
#
# <ATTR_WORDS> disappointing experience <CON_START> staff and manager . <START>
#
# <ATTR_WORDS> did n't respected customer <CON_START> my cut and color and sage is ! <START>
#
# <ATTR_WORDS> people awful place <CON_START> of ages and races . <START>
#
# <ATTR_WORDS> gross poorly <CON_START> had a and the food at their restaurant was ! <START>
#
# <ATTR_WORDS> could <CON_START> at no cost - ! <START>
#
# <ATTR_WORDS> never life me <CON_START> their steak & salsa burrito was very and really too . <START>
#
# <ATTR_WORDS> disappointed <CON_START> blue corn tacos with were . <START>
#
# <ATTR_WORDS> disappointed food sadly <CON_START> to eat and flavor . <START>
#
# <ATTR_WORDS> incredibly salty <CON_START> i will return to the fork ! <START>
#
# <ATTR_WORDS> do location different <CON_START> it will with you all . <START>
#
# <ATTR_WORDS> _num_ stars <CON_START> the hummus is ridiculously and . <START>
#
# <ATTR_WORDS> nothing positive n't go <CON_START> place for a dinner ! <START>
#
# <ATTR_WORDS> ( must n't receipt <CON_START> the owner us and us very well ! <START>
#
# <ATTR_WORDS> better bad bad <CON_START> i say i am so glad we will be moving to . <START>
#
# <ATTR_WORDS> tables neglected n't <CON_START> the chile mac and cheese was ! <START>
#
# <ATTR_WORDS> terrible <CON_START> i highly auto body . <START>
#
# <ATTR_WORDS> taking made feel <CON_START> quality , service . <START>
#
# <ATTR_WORDS> rude ugly <CON_START> and i get the gyro every time and its the . <START>
#
# <ATTR_WORDS> atmosphere mixed children <CON_START> i highly this bakery ! <START>
#
# <ATTR_WORDS> premium food <CON_START> their food and their passion . <START>
#
# <ATTR_WORDS> $ _num_ what <CON_START> i highly this salon and the stylist , angel . <START>
#
# <ATTR_WORDS> disappointment <CON_START> they have a lot of for sushi ! <START>
#
# <ATTR_WORDS> never resort <CON_START> price , bottom line . <START>
#
# <ATTR_WORDS> 's not little <CON_START> tortillas are so ! <START>
#
# <ATTR_WORDS> room not <CON_START> the prices were the best and it . <START>
#
# <ATTR_WORDS> did n't clothes ruined <CON_START> food , service . <START>
#
# <ATTR_WORDS> n't best <CON_START> this was the i have ever had ! <START>
#
# <ATTR_WORDS> wrong thought 's head <CON_START> this is one place in scottsdale dress is . <START>
#
# <ATTR_WORDS> said email <CON_START> i also the fact that they have squeezed orange juice . <START>
#
# <ATTR_WORDS> 'm good reviews <CON_START> the octopus sashimi is my ! <START>
#
# <ATTR_WORDS> building plain _num_ 's decor <CON_START> this is a , especially because of teresa ! <START>
#
# <ATTR_WORDS> seems burns <CON_START> i was with their service . <START>
#
# <ATTR_WORDS> 've customer long <CON_START> you get so much for the price and the is and . <START>
#
# <ATTR_WORDS> _num_ courses <CON_START> they are so and yummy . <START>
#
# <ATTR_WORDS> did n't know <CON_START> the salads were and crispy . <START>

# %%
#for i in trange(conts_neg_vecs.shape[0]):
for i in trange(len(pos_idxs)):
    np_array = conts_pos_vecs[pos_idxs[i]].toarray()[0]
    train1_tree.add_item(i,np_array)
# Out:
# 100%|██████████| 50000/50000 [00:41<00:00, 1210.92it/s]

# %%
model_dir = "/home/jack/Desktop/NN/clean/models/"
train1_tree.build(50)
train1_tree.save(model_dir+'tfidf_train1.ann')
# Out:
# True

# %%
with open(data_dir+"/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/tfidf/reference_0.txt", "w") as out_fp:
    for i in range(conts_from_neg_ref_vecs.shape[0]):
        x = conts_from_neg_ref_vecs[i].toarray()[0]
        inx,dis = train1_tree.get_nns_by_vector(x, 1, include_distances=True)
        ref_sen = ref0_con[i]
        out_str = "<ATTR_WORDS> " + " ".join(attrs_pos[pos_idxs[inx[0]]]) + " <CON_START> " + ref_sen.strip() + " <START>" + "\n"
        print(i, out_str)
        out_fp.write(out_str)
# Out:
# 0 <ATTR_WORDS> prompt friendly <CON_START> ever since joes has changed hands it ' just gotten and . <START>
#
# 1 <ATTR_WORDS> does does well <CON_START> there is not enough room in that part of the . <START>
#
# 2 <ATTR_WORDS> work patrick <CON_START> so basically down . <START>
#
# 3 <ATTR_WORDS> honestly talent talent <CON_START> she she ' d be back and for a few . <START>
#
# 4 <ATTR_WORDS> rest great <CON_START> i n ' t believe how inconsiderate this is . <START>
#
# 5 <ATTR_WORDS> cool slide <CON_START> just and it off the bill . <START>
#
# 6 <ATTR_WORDS> 's lot <CON_START> it is n ' t , but it is n ' t either . <START>
#
# 7 <ATTR_WORDS> love <CON_START> that i could not use my birthday gift ! <START>
#
# 8 <ATTR_WORDS> compassion amazing <CON_START> new , i - but i n ' t know the details . <START>
#
# 9 <ATTR_WORDS> great town <CON_START> but it probably ! <START>
#
# 10 <ATTR_WORDS> definitely continue <CON_START> we down and we got some really and service . <START>
#
# 11 <ATTR_WORDS> lovely <CON_START> the did include miso soup and a salad . <START>
#
# 12 <ATTR_WORDS> food delicious <CON_START> there was i ' m or how did come out . <START>
#
# 13 <ATTR_WORDS> definitely asset <CON_START> we could n ' t at the if we were n ' t ordering dinner . <START>
#
# 14 <ATTR_WORDS> love <CON_START> the cash register area was and one was watching the front . <START>
#
# 15 <ATTR_WORDS> nice <CON_START> there chips are , but their salsa is really . <START>
#
# 16 <ATTR_WORDS> friendly <CON_START> the wine was very and the was even less . <START>
#
# 17 <ATTR_WORDS> guests flavorful <CON_START> by that do n ' t understand customer service . <START>
#
# 18 <ATTR_WORDS> polish flawless good <CON_START> the burgers were over to the point the meat was . <START>
#
# 19 <ATTR_WORDS> nicest <CON_START> dressing was n ' t the by any means . <START>
#
# 20 <ATTR_WORDS> just fish fresh <CON_START> my thai like thai rice with barbeque sauce . <START>
#
# 21 <ATTR_WORDS> super happy <CON_START> she ` ` yes , sorry . <START>
#
# 22 <ATTR_WORDS> favorite quick <CON_START> the is dumpy looking and management to change . <START>
#
# 23 <ATTR_WORDS> burro green amazing <CON_START> there was only meat and . <START>
#
# 24 <ATTR_WORDS> great snack coffee <CON_START> when i in a way , i was out the door . <START>
#
# 25 <ATTR_WORDS> happily answers always <CON_START> she was not being there . <START>
#
# 26 <ATTR_WORDS> happy talk smile <CON_START> moving past the , they were and truly tasteless . <START>
#
# 27 <ATTR_WORDS> hit gym worth <CON_START> the is no longer an option . <START>
#
# 28 <ATTR_WORDS> good greater atmosphere <CON_START> the decor was seriously . <START>
#
# 29 <ATTR_WORDS> nice food everyday <CON_START> , we our and will not return to this location . <START>
#
# 30 <ATTR_WORDS> great <CON_START> the people here are . <START>
#
# 31 <ATTR_WORDS> def return <CON_START> salsa is hot or . <START>
#
# 32 <ATTR_WORDS> tasty <CON_START> i asked for the to be refunded . <START>
#
# 33 <ATTR_WORDS> great food <CON_START> i received a order from them and essentially my money . <START>
#
# 34 <ATTR_WORDS> super great <CON_START> i was n ' going to her do a thing further to . <START>
#
# 35 <ATTR_WORDS> high quality <CON_START> all she did was give the run around and and everything . <START>
#
# 36 <ATTR_WORDS> aesthetic excellent <CON_START> the were in the in the rice was nowhere to be found . <START>
#
# 37 <ATTR_WORDS> everything delicious <CON_START> they to take of me because i young . <START>
#
# 38 <ATTR_WORDS> nevertheless key 's reasonable <CON_START> we ' ve enough there who have returned livid with this restaurant . <START>
#
# 39 <ATTR_WORDS> selection fresh <CON_START> always in their tone and always have customer service ! <START>
#
# 40 <ATTR_WORDS> love service awesome <CON_START> they to work on their customer service and general . <START>
#
# 41 <ATTR_WORDS> good <CON_START> i eating and we back to the beer . <START>
#
# 42 <ATTR_WORDS> all-in-all great spot fest <CON_START> my ` ` hot ' sub was and the meat was . <START>
#
# 43 <ATTR_WORDS> favorite <CON_START> when i first came to phx . . . this to me . <START>
#
# 44 <ATTR_WORDS> did great <CON_START> you n ' t find a in scottsdale . <START>
#
# 45 <ATTR_WORDS> respect nice <CON_START> i asked for thai and very little . <START>
#
# 46 <ATTR_WORDS> friendly helpful <CON_START> i was the night after . <START>
#
# 47 <ATTR_WORDS> nice diverse wildlife <CON_START> i and unsatisfied , never again . <START>
#
# 48 <ATTR_WORDS> location awesome <CON_START> i left this wash and was very unsatisfied ! <START>
#
# 49 <ATTR_WORDS> huge perfect <CON_START> had one mediocre and , ` ` we ' ll try again ' . <START>
#
# 50 <ATTR_WORDS> love <CON_START> the ' s , the service is among the i have encountered . <START>
#
# 51 <ATTR_WORDS> definitely make regular <CON_START> this was my stop in looking for a dress . <START>
#
# 52 <ATTR_WORDS> great buy <CON_START> then he to tell me how to it . <START>
#
# 53 <ATTR_WORDS> thorough <CON_START> do not go to this they are ! <START>
#
# 54 <ATTR_WORDS> great beautiful great <CON_START> i she was n ' t that we were asking the prices . <START>
#
# 55 <ATTR_WORDS> wonderful <CON_START> the only grace was the beans . <START>
#
# 56 <ATTR_WORDS> nice choices <CON_START> a long time ! <START>
#
# 57 <ATTR_WORDS> love <CON_START> other than that , here is pretty . <START>
#
# 58 <ATTR_WORDS> good <CON_START> i was also about another but he straight up off . <START>
#
# 59 <ATTR_WORDS> helpful friendly <CON_START> so i ' not really impressed . <START>
#
# 60 <ATTR_WORDS> great <CON_START> my is only for the two . <START>
#
# 61 <ATTR_WORDS> honest timely <CON_START> has officially my business to sprouts , & & easy . <START>
#
# 62 <ATTR_WORDS> good awesome <CON_START> the food was pretty , i not there again . <START>
#
# 63 <ATTR_WORDS> split friend <CON_START> we will not be this again . <START>
#
# 64 <ATTR_WORDS> always pleasant <CON_START> this is a venue . <START>
#
# 65 <ATTR_WORDS> good <CON_START> you ' ll have appetite after the first . <START>
#
# 66 <ATTR_WORDS> cheese good <CON_START> n ' t here unless you want to pay for . <START>
#
# 67 <ATTR_WORDS> recommend place <CON_START> but it not actually be in anyway . <START>
#
# 68 <ATTR_WORDS> coffee n't service good <CON_START> : a very man . <START>
#
# 69 <ATTR_WORDS> recommended <CON_START> this is a place to live ! <START>
#
# 70 <ATTR_WORDS> recommended friend recommend <CON_START> by for after being at the shop next door . <START>
#
# 71 <ATTR_WORDS> great <CON_START> my was pretty salty and taste the garlic crab . <START>
#
# 72 <ATTR_WORDS> man food good <CON_START> it like up put into the shape of grilled pieces . <START>
#
# 73 <ATTR_WORDS> friendly never sell <CON_START> about the time i ? <START>
#
# 74 <ATTR_WORDS> great eat <CON_START> there are better and better all around mill ! <START>
#
# 75 <ATTR_WORDS> great <CON_START> the rooms are not that and the food is not that either . <START>
#
# 76 <ATTR_WORDS> good <CON_START> chefs would by even saying good morning . <START>
#
# 77 <ATTR_WORDS> huge good <CON_START> this was my indian restaurant . <START>
#
# 78 <ATTR_WORDS> best <CON_START> even brown sauce . <START>
#
# 79 <ATTR_WORDS> quick pleasant <CON_START> i will not revisit this course as a with time to . <START>
#
# 80 <ATTR_WORDS> delicious <CON_START> but was very with what arrived . <START>
#
# 81 <ATTR_WORDS> best <CON_START> his offer of a ` ` free ' was more atrocious . <START>
#
# 82 <ATTR_WORDS> love works <CON_START> i was so i not way for the rest of the . <START>
#
# 83 <ATTR_WORDS> amazing <CON_START> the salads are , special . <START>
#
# 84 <ATTR_WORDS> make fun go <CON_START> overall it was a evening . <START>
#
# 85 <ATTR_WORDS> food good reasonably <CON_START> the woman n ' t even . <START>
#
# 86 <ATTR_WORDS> care shows <CON_START> i expected to be that morning , and it was . <START>
#
# 87 <ATTR_WORDS> solid food <CON_START> with his work . <START>
#
# 88 <ATTR_WORDS> best 've found <CON_START> the garlic bread was and . <START>
#
# 89 <ATTR_WORDS> excellent <CON_START> the espresso was way . <START>
#
# 90 <ATTR_WORDS> treat ... treat <CON_START> i know i should have this back and out . <START>
#
# 91 <ATTR_WORDS> ) <CON_START> they n ' t tell you . <START>
#
# 92 <ATTR_WORDS> pleasant cozy <CON_START> i the food . . . however service here is . <START>
#
# 93 <ATTR_WORDS> friendly <CON_START> gammage itself is not so . <START>
#
# 94 <ATTR_WORDS> love <CON_START> to say i will not be back for . <START>
#
# 95 <ATTR_WORDS> great true <CON_START> i n ' t be again . <START>
#
# 96 <ATTR_WORDS> loved <CON_START> me give my , that ' s what this is for . <START>
#
# 97 <ATTR_WORDS> friendly <CON_START> she not or anything . <START>
#
# 98 <ATTR_WORDS> big lots good <CON_START> prices are retail . <START>
#
# 99 <ATTR_WORDS> love wonderful <CON_START> but this was not economical so the was different . <START>
#
# 100 <ATTR_WORDS> love feel <CON_START> it and like yesterday ' s oil . <START>
#
# 101 <ATTR_WORDS> good <CON_START> who , it have been . <START>
#
# 102 <ATTR_WORDS> 's first delicious <CON_START> the sauce is at best . <START>
#
# 103 <ATTR_WORDS> great <CON_START> the building itself . <START>
#
# 104 <ATTR_WORDS> fresh great <CON_START> we ' ve the cream as well . <START>
#
# 105 <ATTR_WORDS> ladies nice <CON_START> i ' ve had a experience than this ! <START>
#
# 106 <ATTR_WORDS> fantastic family great <CON_START> , i ' at a scottsdale club . <START>
#
# 107 <ATTR_WORDS> great combination enjoy <CON_START> if i could give i def would . <START>
#
# 108 <ATTR_WORDS> recommend friends <CON_START> only now i ' really , and really off . <START>
#
# 109 <ATTR_WORDS> excellent wonderful reuben <CON_START> call , nothing . <START>
#
# 110 <ATTR_WORDS> definitely going <CON_START> i wish i could less than one . <START>
#
# 111 <ATTR_WORDS> eat explore <CON_START> the wonton was seriously . <START>
#
# 112 <ATTR_WORDS> great combination enjoy <CON_START> if i could give , i would . <START>
#
# 113 <ATTR_WORDS> great vibe <CON_START> she not and not explain herself . <START>
#
# 114 <ATTR_WORDS> recommend professional <CON_START> twice - - this place is a . <START>
#
# 115 <ATTR_WORDS> recommended <CON_START> i ' not one of the people . <START>
#
# 116 <ATTR_WORDS> order delicious <CON_START> it ' s always busy and the restaurant is . <START>
#
# 117 <ATTR_WORDS> work patrick <CON_START> even if i was insanely , i n ' t force this down . <START>
#
# 118 <ATTR_WORDS> ordered dishes <CON_START> an arizona native , i have to the improv for years . <START>
#
# 119 <ATTR_WORDS> thanks <CON_START> i there , was pretty quickly , and then my color . <START>
#
# 120 <ATTR_WORDS> good good <CON_START> so , treatment and medication to help me deal with my . <START>
#
# 121 <ATTR_WORDS> bring friends rave <CON_START> at this the service was . <START>
#
# 122 <ATTR_WORDS> delicious too <CON_START> who i call to get my back . <START>
#
# 123 <ATTR_WORDS> nice really liked <CON_START> overcooked so that it was the of tuna fish . <START>
#
# 124 <ATTR_WORDS> first wonderful <CON_START> i ' in a lease otherwise i would move . <START>
#
# 125 <ATTR_WORDS> excellent lovely <CON_START> was a little to begin with . <START>
#
# 126 <ATTR_WORDS> definitely here <CON_START> only then our waitress show up with another styrofoam cup of . <START>
#
# 127 <ATTR_WORDS> bonus <CON_START> the was so - so and over priced for what you . <START>
#
# 128 <ATTR_WORDS> love spice level <CON_START> i to see what their times are when it ' last call . <START>
#
# 129 <ATTR_WORDS> amazing does <CON_START> back to get the tire sealed and filled . <START>
#
# 130 <ATTR_WORDS> great <CON_START> i so much better from this ny . <START>
#
# 131 <ATTR_WORDS> found charge <CON_START> i had to leave a , and they called back . <START>
#
# 132 <ATTR_WORDS> price fair <CON_START> the is than you in the freezer section at walmart . <START>
#
# 133 <ATTR_WORDS> amazing does <CON_START> they tried to get me to come back but i . <START>
#
# 134 <ATTR_WORDS> fills right <CON_START> the security guard upstairs and on our door demanding we up . <START>
#
# 135 <ATTR_WORDS> love <CON_START> i to like this place but it just a big . <START>
#
# 136 <ATTR_WORDS> supercuts great clips <CON_START> i n ' t know worker there get from customer . <START>
#
# 137 <ATTR_WORDS> new comfortable <CON_START> and the is way over . <START>
#
# 138 <ATTR_WORDS> best town <CON_START> they a name for used car dealers . <START>
#
# 139 <ATTR_WORDS> soul rib <CON_START> when i was finally there , i was . <START>
#
# 140 <ATTR_WORDS> feelings adventurous new <CON_START> a frozen patty like a home one . <START>
#
# 141 <ATTR_WORDS> best town <CON_START> but i not going back any more . <START>
#
# 142 <ATTR_WORDS> great family something <CON_START> this is the walmart out of any of them . <START>
#
# 143 <ATTR_WORDS> huge ... bags rare <CON_START> the new team is ! <START>
#
# 144 <ATTR_WORDS> always right thank <CON_START> do n ' t bother anything if you ' re . <START>
#
# 145 <ATTR_WORDS> maybe 'll <CON_START> they also have sight of what deli is . <START>
#
# 146 <ATTR_WORDS> clean items easy <CON_START> the started out . <START>
#
# 147 <ATTR_WORDS> best north <CON_START> i , um . . . no i ' m cool . <START>
#
# 148 <ATTR_WORDS> nice wait n't bad <CON_START> the queen bed was ! <START>
#
# 149 <ATTR_WORDS> nice <CON_START> i ' waiting for an answer . <START>
#
# 150 <ATTR_WORDS> definitely go-to needs lift <CON_START> , i not have asked . <START>
#
# 151 <ATTR_WORDS> really love <CON_START> my toddler a under one of the seats . <START>
#
# 152 <ATTR_WORDS> timed perfectly <CON_START> this place is just . <START>
#
# 153 <ATTR_WORDS> highly recommend <CON_START> i have to say i was . <START>
#
# 154 <ATTR_WORDS> best affordable <CON_START> this is the i will go back . <START>
#
# 155 <ATTR_WORDS> love <CON_START> furthermore , there is or on the menu . <START>
#
# 156 <ATTR_WORDS> become favorites <CON_START> when the finally showed up he was and dismissive ! <START>
#
# 157 <ATTR_WORDS> great <CON_START> the office also to even about this whole experience . <START>
#
# 158 <ATTR_WORDS> great go <CON_START> , way way . <START>
#
# 159 <ATTR_WORDS> answered honest <CON_START> there are smiles and customer service . <START>
#
# 160 <ATTR_WORDS> recommended <CON_START> when she n ' t him quickly enough , he up on her . <START>
#
# 161 <ATTR_WORDS> great <CON_START> the rice was and there was a shit load of it . <START>
#
# 162 <ATTR_WORDS> give <CON_START> if your patio is , you ' out of luck . <START>
#
# 163 <ATTR_WORDS> fun great <CON_START> plus the n ' t even know how to work the . <START>
#
# 164 <ATTR_WORDS> delicious well <CON_START> overall : my business and recommendation for a camera place . <START>
#
# 165 <ATTR_WORDS> specialty fantastic <CON_START> it was so , i her if she was joking ? <START>
#
# 166 <ATTR_WORDS> good reasonable <CON_START> the was mediocre at best , far greasy and not well . <START>
#
# 167 <ATTR_WORDS> love <CON_START> was ( still ) , i had the ribs . <START>
#
# 168 <ATTR_WORDS> amazing great <CON_START> was n ' t , biggie . <START>
#
# 169 <ATTR_WORDS> kind ) <CON_START> the area is special . <START>
#
# 170 <ATTR_WORDS> entertaining good <CON_START> this that he also reeked of smoke ! <START>
#
# 171 <ATTR_WORDS> 's small good <CON_START> also , the that is there is n ' even by buffet standards . <START>
#
# 172 <ATTR_WORDS> knew reviews amazing <CON_START> so i my elsewhere . <START>
#
# 173 <ATTR_WORDS> really enjoy <CON_START> : no more student peeps . <START>
#
# 174 <ATTR_WORDS> loved <CON_START> so from an old . <START>
#
# 175 <ATTR_WORDS> recommend <CON_START> it because on a night there was ' t a long wait . <START>
#
# 176 <ATTR_WORDS> very extremely engaging <CON_START> tzatziki had way much dill in it . <START>
#
# 177 <ATTR_WORDS> such unique love 's <CON_START> the texture of the meat looked and tasted . <START>
#
# 178 <ATTR_WORDS> lots great selection <CON_START> i will never the again . <START>
#
# 179 <ATTR_WORDS> offers fresh fare <CON_START> they only one because you have to a rating . <START>
#
# 180 <ATTR_WORDS> fried steamed delicious <CON_START> i would n ' t there again . <START>
#
# 181 <ATTR_WORDS> good <CON_START> this was by far the rudest i with . <START>
#
# 182 <ATTR_WORDS> enjoyable experience <CON_START> the rest of their is but their employees and service are . <START>
#
# 183 <ATTR_WORDS> fresh cooked love <CON_START> for the food , had it . <START>
#
# 184 <ATTR_WORDS> draw <CON_START> , the nothing to me about this . <START>
#
# 185 <ATTR_WORDS> enjoy especially lovers <CON_START> i ' m from the area and this was a and over . <START>
#
# 186 <ATTR_WORDS> happy store <CON_START> my mom the teriyaki bento box and i the sashimi box . <START>
#
# 187 <ATTR_WORDS>  <CON_START> i bread and fettuccine alfredo pasta with . <START>
#
# 188 <ATTR_WORDS> friendly great <CON_START> it not take that long to sliders ! <START>
#
# 189 <ATTR_WORDS> beautiful <CON_START> the sandwich was not that . <START>
#
# 190 <ATTR_WORDS> great great <CON_START> the did stop her . <START>
#
# 191 <ATTR_WORDS> quite good <CON_START> . . . we told him that we did n ' t want to . <START>
#
# 192 <ATTR_WORDS> love family <CON_START> old , i n ' t believe it . <START>
#
# 193 <ATTR_WORDS> recommend <CON_START> it is also for my taste . <START>
#
# 194 <ATTR_WORDS> great <CON_START> food was we have ordered off the mexican menu . <START>
#
# 195 <ATTR_WORDS> referring friends <CON_START> but not least , their was . . . meh . <START>
#
# 196 <ATTR_WORDS> great bring riding <CON_START> it that this has no class . <START>
#
# 197 <ATTR_WORDS> top places eat <CON_START> one after another they n ' t care to address . <START>
#
# 198 <ATTR_WORDS> fun atmosphere <CON_START> we ' ve been to this many times . <START>
#
# 199 <ATTR_WORDS> true laid-back delicious <CON_START> my plate nearly except for the small container of cole slaw . <START>
#
# 200 <ATTR_WORDS> yep 's <CON_START> when i , one was at the desk . <START>
#
# 201 <ATTR_WORDS> clean <CON_START> we it another 5 - 10 before we got up and . <START>
#
# 202 <ATTR_WORDS> found spot delicious <CON_START> even the ice was very , run of the . <START>
#
# 203 <ATTR_WORDS> made comfortable <CON_START> ' s has been to be with their drink refills for years . <START>
#
# 204 <ATTR_WORDS> fixed guaranteed <CON_START> as as they i was like ugh . <START>
#
# 205 <ATTR_WORDS> avocado <CON_START> the service is mediocre and the is just . <START>
#
# 206 <ATTR_WORDS> good <CON_START> but i darn could have this one . <START>
#
# 207 <ATTR_WORDS> got <CON_START> just is all i say . <START>
#
# 208 <ATTR_WORDS> perfectly great <CON_START> they not have a machine on site ? <START>
#
# 209 <ATTR_WORDS> smile <CON_START> his egg sandwiches like feet and are . <START>
#
# 210 <ATTR_WORDS> great family <CON_START> away , and to cheesecake instead . <START>
#
# 211 <ATTR_WORDS> tastes flavor <CON_START> we there in , because we never expected this . <START>
#
# 212 <ATTR_WORDS> would recommend <CON_START> i ' ve many times , but none as as last night . <START>
#
# 213 <ATTR_WORDS> -- 's very cool pretty <CON_START> way long even if you ' re the only one there . <START>
#
# 214 <ATTR_WORDS> super good ingredients <CON_START> , everyone else after their were completed . <START>
#
# 215 <ATTR_WORDS> loved moment day <CON_START> so , that was my one and only time the there . <START>
#
# 216 <ATTR_WORDS> take-out loved food <CON_START> overall , i do n ' t the much . <START>
#
# 217 <ATTR_WORDS> great unique <CON_START> one of the , but it did n ' t seem very . <START>
#
# 218 <ATTR_WORDS> recommend <CON_START> there is a they get you in fairly quickly . <START>
#
# 219 <ATTR_WORDS> service <CON_START> is stars an option ? <START>
#
# 220 <ATTR_WORDS> great <CON_START> in the run , they absolutely nothing for . <START>
#
# 221 <ATTR_WORDS> fantastic spot grab <CON_START> but this begin at noon today . <START>
#
# 222 <ATTR_WORDS> love store <CON_START> seriously though , i have never . <START>
#
# 223 <ATTR_WORDS> asada yummy <CON_START> it is the place in the valley . <START>
#
# 224 <ATTR_WORDS> good <CON_START> but their inventory was ! <START>
#
# 225 <ATTR_WORDS> happy <CON_START> fried chicken was but the green chili macaroni and cheese was . <START>
#
# 226 <ATTR_WORDS> great <CON_START> so he charge a fortune for them . <START>
#
# 227 <ATTR_WORDS> which spiced sriracha <CON_START> were we her or something ? <START>
#
# 228 <ATTR_WORDS> gets plan high <CON_START> this place has off for the last time . <START>
#
# 229 <ATTR_WORDS> clean friendly <CON_START> not a lease with these people . <START>
#
# 230 <ATTR_WORDS> consistently good <CON_START> n ' t the trip . <START>
#
# 231 <ATTR_WORDS> crispy well <CON_START> had to one entree because too . <START>
#
# 232 <ATTR_WORDS> always favorite <CON_START> the restroom was a . <START>
#
# 233 <ATTR_WORDS> good cultural <CON_START> i that ' been my experience ! <START>
#
# 234 <ATTR_WORDS> best best best <CON_START> the beef taco was but special . <START>
#
# 235 <ATTR_WORDS> great <CON_START> either way i would never from world . <START>
#
# 236 <ATTR_WORDS> made full <CON_START> i to down and wait for my order . <START>
#
# 237 <ATTR_WORDS> love <CON_START> its also a very park . <START>
#
# 238 <ATTR_WORDS> fast <CON_START> i to repeatedly with no response . <START>
#
# 239 <ATTR_WORDS> reminded good home <CON_START> they for work not done , and not installed . <START>
#
# 240 <ATTR_WORDS> quite meal 're <CON_START> it old and outdated . <START>
#
# 241 <ATTR_WORDS> amazing <CON_START> he did return my either . <START>
#
# 242 <ATTR_WORDS> favorite organic <CON_START> if you a lot do not at this . <START>
#
# 243 <ATTR_WORDS> super <CON_START> i rather wait for hot than have it and soggy . <START>
#
# 244 <ATTR_WORDS> great <CON_START> the food here is and and bad . <START>
#
# 245 <ATTR_WORDS> refreshing great <CON_START> this one is on the . <START>
#
# 246 <ATTR_WORDS> wow <CON_START> for the record i a , i use seasoning ! <START>
#
# 247 <ATTR_WORDS> great affordable <CON_START> the package is not an either . <START>
#
# 248 <ATTR_WORDS> great drinks selection n't <CON_START> very crowded , to have a chance to have a time . <START>
#
# 249 <ATTR_WORDS> best sushi <CON_START> i think it ' s when that way . <START>
#
# 250 <ATTR_WORDS> nice great <CON_START> i ' ll keep for a different . <START>
#
# 251 <ATTR_WORDS> beautiful <CON_START> you not me to ever here ! <START>
#
# 252 <ATTR_WORDS> truly best margaritas 've <CON_START> french toast plate was good , mom , but were . <START>
#
# 253 <ATTR_WORDS> one favorite <CON_START> now the not , but below average . <START>
#
# 254 <ATTR_WORDS> food good <CON_START> this is easily the greek i ' ve had in my life . <START>
#
# 255 <ATTR_WORDS> definitely am <CON_START> is what in want to give . <START>
#
# 256 <ATTR_WORDS> great old <CON_START> when it came we have it back . <START>
#
# 257 <ATTR_WORDS> timed perfectly <CON_START> the equipment is so old and . <START>
#
# 258 <ATTR_WORDS> envy great <CON_START> i ' not to take the chance . <START>
#
# 259 <ATTR_WORDS> good fresh <CON_START> this smelt like for some reason . <START>
#
# 260 <ATTR_WORDS> recommend <CON_START> bottom line they over and under . <START>
#
# 261 <ATTR_WORDS> love wonderful <CON_START> i dont know i was anything different . <START>
#
# 262 <ATTR_WORDS> high <CON_START> that about this place . <START>
#
# 263 <ATTR_WORDS> best <CON_START> razz ' on every occasion . <START>
#
# 264 <ATTR_WORDS> organization <CON_START> no longer about the golf experience . <START>
#
# 265 <ATTR_WORDS> plenty entertainment wi-fi <CON_START> - 30 % at most , i was the only one in the . <START>
#
# 266 <ATTR_WORDS> clean friendly <CON_START> the chow was very mushy and had texture . <START>
#
# 267 <ATTR_WORDS> best food <CON_START> the even though it is hard due to signage . <START>
#
# 268 <ATTR_WORDS> thank big ... <CON_START> sure and i n ' t care ! <START>
#
# 269 <ATTR_WORDS> great <CON_START> two of my i never get back . <START>
#
# 270 <ATTR_WORDS> great delicious <CON_START> my red purse and three pair of black . <START>
#
# 271 <ATTR_WORDS> love <CON_START> very and would stay clear of this . <START>
#
# 272 <ATTR_WORDS> 'm cats regular vet <CON_START> service fair , was between courses - long . <START>
#
# 273 <ATTR_WORDS> great great <CON_START> second time , so . <START>
#
# 274 <ATTR_WORDS> amazing <CON_START> the bread was soggy and the was inedible . <START>
#
# 275 <ATTR_WORDS> love tea <CON_START> he n ' t even another time for to come in . <START>
#
# 276 <ATTR_WORDS> came strong raw <CON_START> what the are you doing ? <START>
#
# 277 <ATTR_WORDS> incredible <CON_START> the lady at the desk was very friendly . <START>
#
# 278 <ATTR_WORDS> want hot fresh <CON_START> i was not impressed , and would not this . <START>
#
# 279 <ATTR_WORDS> recommend <CON_START> the dipping sauce was too . <START>
#
# 280 <ATTR_WORDS> ross j 's <CON_START> finally , the cheese was and was anything but . <START>
#
# 281 <ATTR_WORDS> checked lot making <CON_START> i checked online , and the coupon site my was . <START>
#
# 282 <ATTR_WORDS> very nice <CON_START> , , pants on fire . <START>
#
# 283 <ATTR_WORDS> really love fresh <CON_START> parking signs or anything , so you have to guess . <START>
#
# 284 <ATTR_WORDS> always appreciate <CON_START> i have with sun chinese dining . <START>
#
# 285 <ATTR_WORDS> great <CON_START> not so and service . <START>
#
# 286 <ATTR_WORDS> recommended <CON_START> this is an worn out . <START>
#
# 287 <ATTR_WORDS> love <CON_START> the is offered without toppings and it ' in flavor . <START>
#
# 288 <ATTR_WORDS> good food reasonable <CON_START> the are very as usual . <START>
#
# 289 <ATTR_WORDS> great place please <CON_START> this is beyond a hole . <START>
#
# 290 <ATTR_WORDS> highly recommend <CON_START> this is a shit hole with service . <START>
#
# 291 <ATTR_WORDS> new favorite <CON_START> , it out to be like i thought it would . <START>
#
# 292 <ATTR_WORDS> clean well <CON_START> back in for , realized still . <START>
#
# 293 <ATTR_WORDS> hit favorite <CON_START> was just as . <START>
#
# 294 <ATTR_WORDS> nice <CON_START> i do not anyone to this . <START>
#
# 295 <ATTR_WORDS> love <CON_START> the only thing i was offered was a . <START>
#
# 296 <ATTR_WORDS> good <CON_START> not seem to care . <START>
#
# 297 <ATTR_WORDS> sticky chicken w/ best <CON_START> i had a experience , and i not come back . <START>
#
# 298 <ATTR_WORDS> great food <CON_START> it is really rice . <START>
#
# 299 <ATTR_WORDS> honestly <CON_START> n ' t even get a . <START>
#
# 300 <ATTR_WORDS> fresh best <CON_START> needless to say , i the manager directly after . <START>
#
# 301 <ATTR_WORDS> fresh <CON_START> my wife came in for and was treated quite . <START>
#
# 302 <ATTR_WORDS> great great <CON_START> i a cesar salad with a side of . <START>
#
# 303 <ATTR_WORDS> great <CON_START> had it been so , it would have just been inconvenient . <START>
#
# 304 <ATTR_WORDS> nice strong <CON_START> she offer a if i would like a soda while waiting . <START>
#
# 305 <ATTR_WORDS> excellent <CON_START> i to them know but they dont care . <START>
#
# 306 <ATTR_WORDS> food amazing <CON_START> i id forgotten how their offerings really are . <START>
#
# 307 <ATTR_WORDS> good <CON_START> it n ' t get . <START>
#
# 308 <ATTR_WORDS> wonderful <CON_START> we will be back . <START>
#
# 309 <ATTR_WORDS> luckily food good <CON_START> he n ' t actually read her , . <START>
#
# 310 <ATTR_WORDS> phenomenal definitely _num_ stars <CON_START> , do not order from this . <START>
#
# 311 <ATTR_WORDS> salty delicious <CON_START> ass , marquee , so much . <START>
#
# 312 <ATTR_WORDS> best bone <CON_START> even the tasted . <START>
#
# 313 <ATTR_WORDS> cute <CON_START> and the food is as as the other locations . <START>
#
# 314 <ATTR_WORDS> thank louis 're pretty <CON_START> does n ' t it ? <START>
#
# 315 <ATTR_WORDS> bell takes <CON_START> but it was and hot in there . <START>
#
# 316 <ATTR_WORDS> love <CON_START> , the were large , but is n ' t everything . <START>
#
# 317 <ATTR_WORDS> good alright <CON_START> it was over and very . <START>
#
# 318 <ATTR_WORDS> great super <CON_START> i have not such an attitude toward a before . <START>
#
# 319 <ATTR_WORDS> loved `` romantic '' feel <CON_START> the overall are not with frys . <START>
#
# 320 <ATTR_WORDS> attended blast <CON_START> it was at the expense of the other customers . <START>
#
# 321 <ATTR_WORDS> go pretty good <CON_START> we ' ll see if that happens , but i ' not my . <START>
#
# 322 <ATTR_WORDS> hi <CON_START> and ' t do anything about it . <START>
#
# 323 <ATTR_WORDS> great cuts owned <CON_START> wonder these are up all around the valley . <START>
#
# 324 <ATTR_WORDS> absolutely pleasure work <CON_START> what were you going to me when i a dozen ? <START>
#
# 325 <ATTR_WORDS> clean great <CON_START> i ' m still my drunken ! <START>
#
# 326 <ATTR_WORDS> fresh cold amazing <CON_START> these days the is lousy . <START>
#
# 327 <ATTR_WORDS> magnificent <CON_START> this not be in the service industry in with that attitude . <START>
#
# 328 <ATTR_WORDS> favorite <CON_START> service was but not make up for the food and drink . <START>
#
# 329 <ATTR_WORDS> blast great <CON_START> my husband had to to the to place our wine order . <START>
#
# 330 <ATTR_WORDS> great <CON_START> and the pizza was , greasy , and generally . <START>
#
# 331 <ATTR_WORDS> spring pretty good <CON_START> they were having a night ? <START>
#
# 332 <ATTR_WORDS> close seems popular <CON_START> this place is and run down and the service ! <START>
#
# 333 <ATTR_WORDS> love <CON_START> the only thing we that was was the coffee . <START>
#
# 334 <ATTR_WORDS> stunning <CON_START> so , it in the . <START>
#
# 335 <ATTR_WORDS> extremely nice <CON_START> it was for all , though i n ' t think he noticed . <START>
#
# 336 <ATTR_WORDS> thumbs <CON_START> i my online , scheduled an appointment for two days out . <START>
#
# 337 <ATTR_WORDS> nice <CON_START> , i n ' t take any bed with me . <START>
#
# 338 <ATTR_WORDS> need 'll find <CON_START> the is n ' t bad , but the was less than . <START>
#
# 339 <ATTR_WORDS> sweet little children <CON_START> when it finally out , it was . <START>
#
# 340 <ATTR_WORDS> local suggested go <CON_START> talk about so call before you ! <START>
#
# 341 <ATTR_WORDS> service nice <CON_START> the is n ' t too but the service is . <START>
#
# 342 <ATTR_WORDS> best service <CON_START> cakes , , other flavor . <START>
#
# 343 <ATTR_WORDS> love <CON_START> but the customer service it all for . <START>
#
# 344 <ATTR_WORDS> spoke friendly <CON_START> i walked out , called the to . <START>
#
# 345 <ATTR_WORDS> great unique selections <CON_START> i was very with this . <START>
#
# 346 <ATTR_WORDS> cake delicious <CON_START> so you are n ' t my problem . <START>
#
# 347 <ATTR_WORDS> 's patient feels comfortable <CON_START> , the tour are not experts . <START>
#
# 348 <ATTR_WORDS> pleasant <CON_START> i to find a for those uni blocks . . . . <START>
#
# 349 <ATTR_WORDS> definitely <CON_START> she n ' t say anything and away . <START>
#
# 350 <ATTR_WORDS> best know <CON_START> the others the rib hash , also over - and dry . <START>
#
# 351 <ATTR_WORDS> great reasonable <CON_START> the staff was to be . <START>
#
# 352 <ATTR_WORDS> fabulous kind <CON_START> it like melted plastic and had the same tough . <START>
#
# 353 <ATTR_WORDS> love <CON_START> it n ' t matter of she is all other times . <START>
#
# 354 <ATTR_WORDS> friendly <CON_START> i this and he to take care of the bill . <START>
#
# 355 <ATTR_WORDS> food flavorful <CON_START> your & your patience . <START>
#
# 356 <ATTR_WORDS> did excellent job <CON_START> a of my time and theirs . <START>
#
# 357 <ATTR_WORDS> amazing <CON_START> one was for my , and one was for my ' s . <START>
#
# 358 <ATTR_WORDS> love <CON_START> my for looking more closely , i . <START>
#
# 359 <ATTR_WORDS> delivery well worth <CON_START> the server was ' t . <START>
#
# 360 <ATTR_WORDS> thanks <CON_START> service i have ever had . <START>
#
# 361 <ATTR_WORDS> produce great <CON_START> what has happened to this sandwich . <START>
#
# 362 <ATTR_WORDS> found place <CON_START> and for this , i n ' t . <START>
#
# 363 <ATTR_WORDS> good rock music <CON_START> this branch is getting and . <START>
#
# 364 <ATTR_WORDS> friendly walk <CON_START> they to tell us eating in the was an option . <START>
#
# 365 <ATTR_WORDS> new <CON_START> they can thank you for the . <START>
#
# 366 <ATTR_WORDS> fantastic <CON_START> i n ' t even it . <START>
#
# 367 <ATTR_WORDS> open great run <CON_START> this was the time i ever from a haircut . <START>
#
# 368 <ATTR_WORDS> best working 'd <CON_START> there was to our server . <START>
#
# 369 <ATTR_WORDS> great very nice <CON_START> if i was n ' with my , i would ' ve out . <START>
#
# 370 <ATTR_WORDS> fabulous <CON_START> i n ' t know was a chain . <START>
#
# 371 <ATTR_WORDS> 's great nice <CON_START> i ' sure they must get it some days but this day . <START>
#
# 372 <ATTR_WORDS> very good <CON_START> to the brunch to our daughter ' s college graduation . <START>
#
# 373 <ATTR_WORDS> deep <CON_START> this is the third time they ' ve up that . <START>
#
# 374 <ATTR_WORDS> always excellent <CON_START> the is a of time , energy and money . <START>
#
# 375 <ATTR_WORDS> best airport <CON_START> i also him i would leave him some online . <START>
#
# 376 <ATTR_WORDS> work experienced <CON_START> , the came back told me my order was coming up . <START>
#
# 377 <ATTR_WORDS> happy <CON_START> is that a thing or a thing ? <START>
#
# 378 <ATTR_WORDS> entertaining upbeat <CON_START> maria the is a person . <START>
#
# 379 <ATTR_WORDS> comfortable <CON_START> it was much good that i wanted out of there . <START>
#
# 380 <ATTR_WORDS> fast professional outstanding <CON_START> we them to it , we n ' t want to wait . <START>
#
# 381 <ATTR_WORDS> best <CON_START> first , the was an a - - . <START>
#
# 382 <ATTR_WORDS> gorgeous center <CON_START> stay away from this place . <START>
#
# 383 <ATTR_WORDS> big fan <CON_START> i guess even restaurants have days . <START>
#
# 384 <ATTR_WORDS> delicious <CON_START> well , who cares . . . ? <START>
#
# 385 <ATTR_WORDS> worth <CON_START> we will spend our elsewhere . <START>
#
# 386 <ATTR_WORDS> pretty def <CON_START> i will never another lv again . <START>
#
# 387 <ATTR_WORDS> love <CON_START> pieces and apart - - i for that . <START>
#
# 388 <ATTR_WORDS> liked approach <CON_START> we n ' t leave with that . <START>
#
# 389 <ATTR_WORDS> great <CON_START> , horrible , service ! <START>
#
# 390 <ATTR_WORDS> made 's weekend n't disappointed <CON_START> now it is so and like any other pizza place . <START>
#
# 391 <ATTR_WORDS> got good <CON_START> this piece of shit wonton crackers for my . <START>
#
# 392 <ATTR_WORDS> love live <CON_START> i ' m a of chain restaurants . <START>
#
# 393 <ATTR_WORDS> easy car <CON_START> the rice was and hard and the taste was very . <START>
#
# 394 <ATTR_WORDS> always remembers <CON_START> you not judge based on appearance . <START>
#
# 395 <ATTR_WORDS> always happy <CON_START> you are the only place in town with pizza . <START>
#
# 396 <ATTR_WORDS> highly recommend place n't <CON_START> the thai pasta came out lukewarm and . <START>
#
# 397 <ATTR_WORDS> favorite <CON_START> courtesy and their food is . <START>
#
# 398 <ATTR_WORDS> love <CON_START> i would never reccomend anyone to . <START>
#
# 399 <ATTR_WORDS> blast sweet <CON_START> had to a to get in . <START>
#
# 400 <ATTR_WORDS> fantastic chicken <CON_START> food but staff and very very workers ! <START>
#
# 401 <ATTR_WORDS> happy found <CON_START> it was my weekend my folks . <START>
#
# 402 <ATTR_WORDS> reasonable <CON_START> next was moo goo gai pan to which the is the . <START>
#
# 403 <ATTR_WORDS> buffet great selection <CON_START> do not here if you are in eating food . <START>
#
# 404 <ATTR_WORDS> definitely vacation <CON_START> prime was and not cooked per requested . <START>
#
# 405 <ATTR_WORDS> great experience <CON_START> i all respect for this company . <START>
#
# 406 <ATTR_WORDS> n't hear gets packed <CON_START> to say we will be to other walgreens from now on . <START>
#
# 407 <ATTR_WORDS> recommend <CON_START> i may make it back to the but i will the . <START>
#
# 408 <ATTR_WORDS> friendly <CON_START> me tell you , this was far from ! <START>
#
# 409 <ATTR_WORDS> wonderful <CON_START> it ' not much like an irish , which is depressing . <START>
#
# 410 <ATTR_WORDS> greet enter <CON_START> the surprise has been as well as her day . <START>
#
# 411 <ATTR_WORDS> happy hour great 1/2 <CON_START> in this price was a card fee and an after fee . <START>
#
# 412 <ATTR_WORDS> quite good <CON_START> the only was to was the soggy broccoli beef ! <START>
#
# 413 <ATTR_WORDS> heaven <CON_START> other than that , i n ' t know what was about it . <START>
#
# 414 <ATTR_WORDS> great <CON_START> the food is not that . <START>
#
# 415 <ATTR_WORDS> ordered _num_ thought very <CON_START> , keep walking . <START>
#
# 416 <ATTR_WORDS> warm friendly <CON_START> unfortunately , it is the . <START>
#
# 417 <ATTR_WORDS> great find <CON_START> the has obviously gone over the years . <START>
#
# 418 <ATTR_WORDS> salty delicious <CON_START> so much these . <START>
#
# 419 <ATTR_WORDS> change <CON_START> n ' like dealing with the restaurants closer to asu . <START>
#
# 420 <ATTR_WORDS> delicious <CON_START> this is the panda express there is ! <START>
#
# 421 <ATTR_WORDS> loves animals <CON_START> the n ' t at all . <START>
#
# 422 <ATTR_WORDS> yeah <CON_START> my services were and she did n ' t even do a job . <START>
#
# 423 <ATTR_WORDS> excellent great amazing <CON_START> the ceiling air conditioner in the is very . <START>
#
# 424 <ATTR_WORDS> food good <CON_START> we placed our order with our extremely and apparently completely server . <START>
#
# 425 <ATTR_WORDS> best played <CON_START> i post to prove their shoddy work . <START>
#
# 426 <ATTR_WORDS> local cute <CON_START> it is way ( compare to what they ! <START>
#
# 427 <ATTR_WORDS> 'm making hair <CON_START> this is a college . <START>
#
# 428 <ATTR_WORDS> good greater atmosphere <CON_START> my jack and was seriously . <START>
#
# 429 <ATTR_WORDS> excellent <CON_START> , i will probably never be to eat at this again . <START>
#
# 430 <ATTR_WORDS> best bell <CON_START> the falafel ' s like nuggets , and were flavor . <START>
#
# 431 <ATTR_WORDS> very good <CON_START> i looked around and there were . <START>
#
# 432 <ATTR_WORDS> favorite y <CON_START> i it was to even serve this to diners . <START>
#
# 433 <ATTR_WORDS> always good <CON_START> we both it overcooked - - and seasonings . <START>
#
# 434 <ATTR_WORDS> found place <CON_START> in turn my legs are from the and all over the . <START>
#
# 435 <ATTR_WORDS> great friendly <CON_START> if at all . <START>
#
# 436 <ATTR_WORDS> delicious <CON_START> i not like to be over , or changed . <START>
#
# 437 <ATTR_WORDS> recommend ice chest <CON_START> we asked how long the would be , she she was . <START>
#
# 438 <ATTR_WORDS> far best <CON_START> it ' just for what you get . <START>
#
# 439 <ATTR_WORDS> high quality <CON_START> also , they a single pack of cheese or red peppers ? <START>
#
# 440 <ATTR_WORDS> definitely back <CON_START> into this location to it off . <START>
#
# 441 <ATTR_WORDS> best around <CON_START> we there on a busy holiday weekend and the service was . <START>
#
# 442 <ATTR_WORDS> spicy love <CON_START> if i was the , i ' d that kid on the . <START>
#
# 443 <ATTR_WORDS> rocks so <CON_START> too bad too because they an beer . <START>
#
# 444 <ATTR_WORDS> just perfect <CON_START> the was quality and together quickly with little flavor . <START>
#
# 445 <ATTR_WORDS> great <CON_START> the beer was and cold ! <START>
#
# 446 <ATTR_WORDS> best bakery <CON_START> the woman who in the deli is . <START>
#
# 447 <ATTR_WORDS> reasonable <CON_START> will never go back to they essentially from me ! <START>
#
# 448 <ATTR_WORDS> service sweetest friendly <CON_START> there are much for breakfast . <START>
#
# 449 <ATTR_WORDS> first good watches <CON_START> the surly waitress was a bummer . <START>
#
# 450 <ATTR_WORDS> selection great <CON_START> it ' not my fave , but it ' not . <START>
#
# 451 <ATTR_WORDS> favorite <CON_START> , yah , it n ' t need just yet . <START>
#
# 452 <ATTR_WORDS> gem <CON_START> place , food . <START>
#
# 453 <ATTR_WORDS> great maintenance <CON_START> to say , i will not be to this ever again . <START>
#
# 454 <ATTR_WORDS> loved <CON_START> , their are higher than other places . <START>
#
# 455 <ATTR_WORDS> always good <CON_START> anything they , in writing . <START>
#
# 456 <ATTR_WORDS> always home food <CON_START> this is a cry from new mexican cuisine . <START>
#
# 457 <ATTR_WORDS> loved eateries <CON_START> but the woman was the one checking us out . <START>
#
# 458 <ATTR_WORDS> loved <CON_START> in cabinets in kitchen and bathroom along with are kept up . <START>
#
# 459 <ATTR_WORDS> authentic myself wants <CON_START> service in these areas and really our visit . <START>
#
# 460 <ATTR_WORDS> great <CON_START> if i had wanted it i would have it myself ! <START>
#
# 461 <ATTR_WORDS> clean cozy <CON_START> she grabbed a couple dishes and walked off . <START>
#
# 462 <ATTR_WORDS> good <CON_START> , price specials and the occasional groupon . <START>
#
# 463 <ATTR_WORDS> excellent unique <CON_START> the enchiladas were but not great . <START>
#
# 464 <ATTR_WORDS> highly recommend <CON_START> the is nothing was good . <START>
#
# 465 <ATTR_WORDS> reasonable <CON_START> i to no . <START>
#
# 466 <ATTR_WORDS> good <CON_START> is also almost as as living on . <START>
#
# 467 <ATTR_WORDS> 's fresh fabulous <CON_START> job on and toes . <START>
#
# 468 <ATTR_WORDS> good thing n't sound <CON_START> i to purchase any of the based on . <START>
#
# 469 <ATTR_WORDS> works bought <CON_START> be offered at no charge . <START>
#
# 470 <ATTR_WORDS> day like <CON_START> , there are far places to for sushi . <START>
#
# 471 <ATTR_WORDS> good taste <CON_START> my suite to get and a new put on it . <START>
#
# 472 <ATTR_WORDS> great <CON_START> sketchy sketchy pizza ! <START>
#
# 473 <ATTR_WORDS> super good ingredients <CON_START> that didnt get their until everyone else was finished with their . <START>
#
# 474 <ATTR_WORDS> 's outstanding <CON_START> the is , i ' sure she could have figured it out . <START>
#
# 475 <ATTR_WORDS> owned definitely <CON_START> they , and do n ' t pay attention to their . <START>
#
# 476 <ATTR_WORDS> easily eat <CON_START> but nothing special . <START>
#
# 477 <ATTR_WORDS> place better <CON_START> with my manicure or pedicure . <START>
#
# 478 <ATTR_WORDS> reasonable <CON_START> i at 6 : 30 and the complete off . <START>
#
# 479 <ATTR_WORDS> best salon <CON_START> , this went pretty smooth . <START>
#
# 480 <ATTR_WORDS> good <CON_START> they ' nowhere near any that out . <START>
#
# 481 <ATTR_WORDS> reliable local <CON_START> since their visit , the we ' ve seen were ! <START>
#
# 482 <ATTR_WORDS> recommend booking extra <CON_START> she was getting , and were we . <START>
#
# 483 <ATTR_WORDS> friendly laugh excellent <CON_START> n ' seem to about their job . <START>
#
# 484 <ATTR_WORDS> fantastic <CON_START> would have if i could . <START>
#
# 485 <ATTR_WORDS> really great 'm excited <CON_START> personalized or at all . <START>
#
# 486 <ATTR_WORDS> charming great <CON_START> one person would while everyone else was and waiting for theirs . <START>
#
# 487 <ATTR_WORDS> great place <CON_START> i do not like the of the floor . <START>
#
# 488 <ATTR_WORDS> high quality <CON_START> this is busy and could use double the staff . <START>
#
# 489 <ATTR_WORDS> super-friendly <CON_START> i customer services is only at some locations . <START>
#
# 490 <ATTR_WORDS> favorite town <CON_START> their i ' m certain was of the variety . <START>
#
# 491 <ATTR_WORDS> nice <CON_START> , not the at asu , the ones in junior . <START>
#
# 492 <ATTR_WORDS> perfection <CON_START> three for lunch last friday at at the sanctuary . <START>
#
# 493 <ATTR_WORDS> love <CON_START> sushi , you are so to me . <START>
#
# 494 <ATTR_WORDS> best sandwich 've <CON_START> half of my was over . <START>
#
# 495 <ATTR_WORDS> great <CON_START> an dude my pedicure . <START>
#
# 496 <ATTR_WORDS> really improved top <CON_START> it ' been in a fridge for a week . <START>
#
# 497 <ATTR_WORDS> great great great <CON_START> ` , we are going to have a tomorrow . <START>
#
# 498 <ATTR_WORDS> worth <CON_START> when i up the , i was given another totally different . <START>
#
# 499 <ATTR_WORDS> best food friendly <CON_START> they not some of the most common . <START>
