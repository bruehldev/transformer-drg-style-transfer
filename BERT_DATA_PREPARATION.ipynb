# %%
import csv
import logging
import os
import random
import sys

import numpy as np
import torch
from torch.utils.data import (DataLoader, RandomSampler, SequentialSampler,
                              TensorDataset)
from torch.utils.data.distributed import DistributedSampler
from tqdm import tqdm, trange

from pytorch_pretrained_bert.file_utils import PYTORCH_PRETRAINED_BERT_CACHE
from pytorch_pretrained_bert.modeling import BertForSequenceClassification, BertConfig, WEIGHTS_NAME, CONFIG_NAME
#from pytorch_pretrained_bert.tokenization import BertTokenizer
from pytorch_pretrained_bert.optimization import BertAdam, warmup_linear

from bertviz.bertviz import attention, visualization
from bertviz.bertviz.pytorch_pretrained_bert import BertModel, BertTokenizer
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.

# %%
logger = logging.getLogger(__name__)
bert_classifier_model_dir = "../models/BERT/" ## Path of BERT classifier model path
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
logger.info("device: {}, n_gpu {}".format(device, n_gpu))

# %%
# file paths
data_dir = "/home/jack/Desktop/NN/clean/datasets/"
dataset = "yelp" # amazon / yelp / imagecaption
train_0 = os.path.join(data_dir ,"{}/sentiment.train.0".format(dataset))
train_1 = os.path.join(data_dir,"{}/sentiment.train.1".format(dataset))
test_0 = os.path.join(data_dir,"{}/sentiment.test.0".format(dataset))
test_1 = os.path.join(data_dir,"{}/sentiment.test.1".format(dataset))
dev_0 = os.path.join(data_dir,"{}/sentiment.dev.0".format(dataset))
dev_1 = os.path.join(data_dir,"{}/sentiment.dev.1".format(dataset))
reference_0 = os.path.join(data_dir,"{}/reference.0".format(dataset))
reference_1 = os.path.join(data_dir,"{}/reference.1".format(dataset))

reference_0_org = os.path.join(data_dir,"{}/reference_0_org.txt".format(dataset))
reference_1_org = os.path.join(data_dir,"{}/reference_1_org.txt".format(dataset))
reference_0_expected = os.path.join(data_dir,"{}/reference_0_expected.txt".format(dataset))
reference_1_expected = os.path.join(data_dir,"{}/reference_1_expected.txt".format(dataset))

# %%
def read_file(file_path):
    with open(file_path) as fp:
        data = fp.read().splitlines()
    return data

# %%
def split_Ref(ref_file_path, target_file_path, target_split):
    open_File = read_file(ref_file_path)
    #target_file = read_file(target_file_path)
    with open(target_file_path, "w") as target_file:
        for ref_line in open_File:
            print(ref_line.split("	")[target_split])
            target_file.write(ref_line.split("	")[target_split]+"\n")
            
        
split_Ref(reference_0,reference_0_org, 0)
split_Ref(reference_0,reference_0_expected, 1)
split_Ref(reference_1,reference_1_org, 0)
split_Ref(reference_1,reference_1_expected, 1)
# Out:
# ever since joes has changed hands it 's just gotten worse and worse .
# there is definitely not enough room in that part of the venue .
# so basically tasted watered down .
# she said she 'd be back and disappeared for a few minutes .
# i ca n't believe how inconsiderate this pharmacy is .
# just left and took it off the bill .
# it is n't terrible , but it is n't very good either .
# definitely disappointed that i could not use my birthday gift !
# new owner , i heard - but i do n't know the details .
# but it probably sucks too !
# we sit down and we got some really slow and lazy service .
# the charge did include miso soup and a small salad .
# there was no i 'm sorry or how did everything come out .
# said we could n't sit at the table if we were n't ordering dinner .
# the cash register area was empty and no one was watching the store front .
# there chips are ok , but their salsa is really bland .
# the wine was very average and the food was even less .
# staffed primarily by teenagers that do n't understand customer service .
# the burgers were over cooked to the point the meat was crunchy .
# blue cheese dressing was n't the best by any means .
# my pad thai tasted like thai rice noodles with barbeque sauce .
# she said `` yes , sorry . ''
# the store is dumpy looking and management needs to change .
# there was only meat and bread .
# when i complained in a polite way , i was walked out the door .
# she was not happy being there .
# moving past the shape , they were dry and truly tasteless .
# the associates program is no longer an option .
# the decor was seriously lacking .
# anyway , we got our coffee and will not return to this location .
# the sales people here are terrible .
# salsa is not hot or good .
# so i asked for the card to be refunded .
# i just received a delivery order from them and essentially wasted my money .
# i was n't going to let her do a thing further to me .
# all she did was give me the run around and lied and bs everything .
# the beans were in the burro in the rice was nowhere to be found .
# they tried to take advantage of me because i am young .
# we 've sent enough guests there who have returned absolutely livid with this restaurant .
# always rude in their tone and always have shitty customer service !
# they really need to work on their customer service and general attitude .
# i skipped eating and we went back to the beer .
# my `` hot '' sub was cold and the meat was watery .
# when i first came to phx ... yes this sounded indian to me .
# you wo n't find a better selection in scottsdale .
# i asked for thai hot and received very little spice .
# i was very sick the night after .
# i left hungry and unsatisfied , never again .
# i just left this car wash and was very unsatisfied !
# had one mediocre meal and said , `` we 'll try again '' .
# the food 's ok , the service is among the worst i have encountered .
# this was my first stop in looking for a wedding dress .
# then he proceeded to tell me how to fix it .
# do not go to this practice they are horrible !
# i guess she was n't happy that we were asking the prices .
# the only saving grace was the black beans .
# lost a long time customer !
# other than that , food here is pretty gross .
# i was also curious about another product but he straight up walked off .
# so far i 'm not really impressed .
# my groupon is only for the two windows .
# safeway has officially lost my business to sprouts , & fresh & easy .
# the food was pretty bad , i would not go there again .
# we will not be using this location again .
# this is a horrible venue .
# you 'll have zero appetite after the first bite .
# do n't go here unless you want to pay for crap .
# but it may not actually be in stock anyway .
# owner : a very rude man .
# this place is a terrible place to live !
# stopped by for soda after being at the hobby shop next door .
# my dish was pretty salty and could barely taste the garlic crab .
# it looks like blended up chicken put into the shape of grilled pieces .
# what about the time i wasted ?
# there are better happy hours and better beers all around mill !
# the rooms are not that nice and the food is not that good either .
# executive chefs would walk by not even saying good morning .
# this spot was my favorite indian restaurant .
# not even real brown sauce .
# i will not revisit this course as a visitor with limited time to play .
# but was very disappointed with what actually arrived .
# his offer of a `` free dessert '' was even more atrocious .
# i was so disgusted i could not way for the rest of the day .
# the salads are ok , nothing special .
# overall it was a miserable evening .
# the woman did n't even apologize .
# i expected service to be slow that morning , and it was .
# zero complaints with his work .
# the garlic bread was bland and cold .
# the espresso was way too hot .
# i know i should have sent this back and walk out .
# they wo n't tell you though .
# i love the food ... however service here is horrible .
# gammage itself however is not so amazing .
# needless to say i will not be back for mexican food .
# i wo n't be ordering again .
# let me give my opinion , that 's what this site is for .
# she did not apologize or anything .
# prices are just plain retail .
# but this place was not economical so the expectation was different .
# it smelled and tasted like yesterday 's oil .
# who knows , it might have been .
# the beer sauce is lackluster at best .
# the building itself looks abandoned .
# we 've tried the cream pancakes as well .
# i 've never had a worse experience than this !
# no , i 'm not at a scottsdale club .
# if i could give zero stars i def would .
# only now i 'm really hungry , and really pissed off .
# no call , no nothing .
# i wish i could give less than one star .
# the wonton was seriously lacking filling .
# if i could give less stars , i would .
# she could not and would not explain herself .
# think twice -- this place is a dump .
# i 'm not one of the corn people .
# it 's always busy and the restaurant is very dirty .
# even if i was insanely drunk , i could n't force this pizza down .
# as an arizona native , i have been going to the improv for years .
# i got there , was seated pretty quickly , and then chose my color .
# so , no treatment and no medication to help me deal with my condition .
# at this location the service was terrible .
# so who do i call to get my money back .
# overcooked so badly that it was the consistency of canned tuna fish .
# i 'm stuck in a lease otherwise i would move .
# service was a little slow to begin with .
# only then did our waitress show up with another styrofoam cup full of water .
# the food was so-so and very over priced for what you get .
# i hate to see what their delivery times are when it 's last call .
# just went back to get the rear tire sealed and filled .
# i expected so much better from this ny staple .
# i had to leave a message , and they never called me back .
# the food is worse than you find in the freezer section at walmart .
# they tried real hard to get me to come back but i refused .
# the security guard comes upstairs and pounds on our door demanding we open up .
# i wanted to like this place but it just became a big disappointment .
# i did n't know worker there can get tips from customer .
# and the cleaning is way over priced .
# they make a bad name for used car dealers .
# when i was finally there , i was very disappointed .
# just a frozen patty cooked like a home one .
# so sad but i am not going back any more .
# this is the worst walmart neighborhood market out of any of them .
# the new management team is horrible !
# just do n't bother ordering anything if you 're seated .
# they also have lost sight of what good deli food is .
# the evening started out slow .
# i replied , '' um ... no i 'm cool .
# the queen bed was horrible !
# meanwhile i 'm waiting for an answer .
# oh , i should not have asked .
# my toddler found a dead mouse under one of the seats .
# this place is just ok .
# i have to say i was truly disappointed .
# this is the reason i will never go back .
# furthermore , there is no sausage or bacon on the menu .
# when the manager finally showed up he was rude and dismissive !
# the office also failed to even apologize about this whole horrific experience .
# nope , way way worse .
# there are no smiles and no customer service .
# when she did n't answer him quickly enough , he hung up on her .
# the fried rice was gross and there was a shit load of it .
# if your patio is south facing , you 're out of luck .
# plus the dude did n't even know how to work the computer .
# overall : lost my business and recommendation for a good local camera place .
# it was so odd , i asked her if she was joking ?
# the food was mediocre at best , far too greasy and not cooked well .
# food was cold ( still frozen ) , i had the ribs .
# was n't busy , no biggie .
# the bathroom area is nothing special .
# this room that he found also reeked of smoke !
# also , the food that is there is n't great even by buffet standards .
# so i brought my business elsewhere .
# exhibit c : no more student services peeps .
# so disappointing from an old favorite .
# it shows because on a saturday night there was n't a long wait .
# tzatziki sauce had way too much dill in it .
# the texture of the meat just looked and tasted wrong .
# i will never visit the salon again .
# they only received one star because you have to provide a rating .
# i would n't go back there again .
# this was by far the rudest person i spoke with .
# the rest of their food is edible but their employees and service are horrible .
# as for the food , never had it .
# however , the tech said nothing to me about this .
# i 'm from the bay area and this was a disappointment and over priced .
# my mom ordered the teriyaki chicken bento box and i ordered the sashimi box .
# i ordered garlic bread and fettuccine alfredo pasta with vegetables .
# it does not take that long to cook sliders !
# the sandwich was not that great .
# the man did not stop her .
# um ... we just told him that we did n't want to finance .
# tasted really old , i could n't believe it .
# it is also quite expensive for my taste .
# food was alright maybe we should have ordered off the mexican menu .
# lastly but not least , their brownie desert was ... meh .
# it shows that this restaurant has no class .
# one broken thing after another they do n't care to address .
# we 've been to this long established restaurant many times .
# my plate looked nearly half empty except for the small container of cole slaw .
# when i arrived , no one was at the desk .
# we gave it another 5-10 minutes before we got up and left .
# even the ice cream was very , very run of the mill .
# wendy 's has been know to be cheap with their drink refills for years .
# as soon as they delivered i was like ugh .
# the service is mediocre and the restaurant is just average .
# but i darn sure could have cooked this one .
# just terrible is all i can say .
# did they not have a fountain machine on site ?
# his egg sandwiches stink like feet and are slimy .
# stay away , and go to cheesecake instead .
# we stood there in shock , because we never expected this .
# i 've eaten here many times , but none as bad as last night .
# always takes way too long even if you 're the only one there .
# however , everyone else paid after their nails were completed .
# so , that was my one and only time ordering the benedict there .
# overall , i do n't enjoy the place very much .
# one of the employees apologized , but it did n't seem very sincere .
# there is a reason they can get you in fairly quickly .
# is zero stars an option ?
# in the long run , they did absolutely nothing for me .
# but let this story begin at noon today .
# seriously though , i have never shopped here .
# it is the absolute worse place in the valley .
# but their inventory was questionable !
# chicken fried chicken was dry but the green chili macaroni and cheese was good .
# so he can charge a bloody fortune for them .
# were we irritating her or something ?
# this place has pissed me off for the last time .
# do not sign a lease with these people .
# do n't waste the trip .
# had to returned one entree because too cold .
# the restroom was a mess .
# i mean that 's been my experience !
# the beef taco was good but nothing special .
# either way i would never recommend buying from camping world .
# i went to sit down and wait for my order .
# its also not a very clean park .
# i tried to call repeatedly with no response .
# they charged me for work not done , and parts not installed .
# it looks old and outdated .
# he did not return my call either .
# if you travel a lot do not stay at this hotel .
# i would rather wait for hot food than have it cold and soggy .
# the food here is bland and boring and bad .
# this one is not on the ball .
# for the record i am a good cook , i use seasoning !
# the tow package is not an issue either .
# very crowded , difficult to have a chance to actually have a good time .
# i think it 's terrible when employees act that way .
# i 'll keep looking for a different salon .
# you can not pay me to ever shop here !
# french toast plate was good , mom said , but eggs were cold .
# now the food : not horrible , but below average .
# this is easily the worst greek food i 've had in my life .
# no stars is what in want to give .
# when it came we should have sent it back .
# the equipment is so old and looks dirty .
# i 'm not willing to take the chance .
# this place smelt like old urine for some reason .
# bottom line they over promise and under deliver .
# i dont know why i was expecting anything different .
# nothing that special about this place .
# razz 's failed on every occasion .
# management no longer cares about the golf experience .
# 20-30 % capacity at most , i was the only one in the pool .
# the chow mein was very mushy and had weird texture .
# found the place even though it is hard due to bad signage .
# not sure and i do n't care !
# two hours of my life i can never get back .
# dropped off my red purse and three pair of black shoes .
# very disappointed and would stay clear of this place .
# service fair , pace was bad between courses - long waits .
# second time , not so good .
# the bread was soggy and the dip was inedible .
# he did n't even offer another time for me to come in .
# what the hell are you doing ?
# the lady at the front desk was not very friendly .
# i was not impressed , and would not recommend this place .
# the dipping sauce was too sweet too .
# finally , the cheese crisp was tiny and was anything but crisp .
# i checked online , and the coupon site said my certificate was good .
# liar , liar , pants on fire .
# parking : no signs or anything , so you just have to guess .
# i should have stuck with sun chinese dining .
# not so great food and service .
# this is an old worn out hotel .
# the pizza is offered without toppings and it 's lacking in flavor .
# the mechanics are very amateur as usual .
# this place is beyond a shit hole .
# this place is a shit hole with shit service .
# however , it turned out to be nothing like i thought it would .
# went back in for adjustment , realized still incorrect .
# service was just as disappointing .
# i do not recommend anyone to this starbucks .
# the only thing i was offered was a free dessert .
# management does not seem to care .
# i had a horrible experience , and i sadly would not come back .
# it is not really brown rice .
# did n't even get a response .
# needless to say , i contacted the store manager directly after leaving .
# my wife came in for alterations and was treated quite rudely .
# i ordered a cesar salad with a side of blackened chicken .
# had it not been so terribly hot , it would have just been inconvenient .
# she did offer me a copy if i would like a soda while waiting .
# i emailed to let them know but they apparently dont care .
# i suppose id forgotten how bland their offerings really are .
# it did n't get finished .
# we will not be coming back .
# he could n't actually read her pressure , though .
# absolutely terrible , do not order from this place .
# ate kicked ass , marquee , not so much .
# even the water tasted horrible .
# and the food is simply not as good as the other locations .
# sounds good does n't it ?
# but it was disgusting and hot in there .
# yes , the portions were large , but size is n't everything .
# it was over fried and very hard .
# i have not received such an attitude toward a customer before .
# the overall prices are not competitive with frys .
# too bad it was at the expense of the other customers .
# we 'll see if that happens , but i 'm not holding my breath .
# and management does n't do anything about it .
# no wonder these restaurants are closing up all around the valley .
# what were you going to charge me when i purchase a dozen bagels ?
# i 'm still craving my drunken noodles !
# these days the quality is pretty lousy .
# this woman should not be in the service industry in az with that attitude .
# service was average but could not make up for the poor food and drink .
# my husband had to walk up to the bar to place our wine order .
# and the pizza was cold , greasy , and generally quite awful .
# maybe they were having a bad night ?
# this place is dirty and run down and the service stinks !
# the only thing we received that was hot was the coffee .
# so , it went in the trash .
# it was embarrassing for all involved , though i do n't think he noticed .
# so i ordered my tires online , scheduled an appointment for two days out .
# hopefully , i do n't take any bed bugs with me .
# the beer is n't bad , but the food was less than desirable .
# when it finally came out , it was bad .
# talk about false advertising so call before you go !
# the food is n't too bad but the service is terrible .
# crab cakes , salt , no other flavor .
# but the customer service ruins it all for me .
# i just walked out , called the manager to complain .
# i was very disappointed with this place .
# so you are n't my problem . ''
# unfortunately , the tour guides are not experts .
# geez i need to find a source for those uni blocks ... .
# she does n't say anything and just walks away .
# the others ordered the short rib hash , also over-cooked and dry .
# the staff was nowhere to be found .
# it tasted like melted plastic and had the same tough consistency .
# it did n't matter of she is good at all other times .
# i acknowledged this and he went back to take care of the bill .
# save your money & your patience .
# what a waste of my time and theirs .
# one was for my dog , and one was for my wife 's dog .
# my fault for not looking more closely , i guess .
# the server was n't buying .
# worst customer service i have ever had .
# sad what has happened to this sandwich shop .
# and for this reason , i wo n't return .
# this branch is getting worse and worse .
# they failed to tell us eating in the bar was an option .
# they can thank you for the low rating .
# i did n't even eat it .
# this was the first time i ever cried from a haircut .
# there was no personality to our server .
# if i was n't with my coworker , i would 've walked out .
# i did n't know ra was a chain .
# i 'm sure they must get it right some days but not this day .
# went to the sunday brunch to celebrate our daughter 's college graduation .
# this is the third time they 've messed up that spice .
# the game room is a waste of time , energy and money .
# i also told him i would leave him some good feedback online .
# however , the manager came back & told me my order was coming up .
# is that a good thing or a bad thing ?
# maria the manager is a horrible person .
# it was so much not good that i just wanted out of there .
# we told them to forget it , we did n't want to wait .
# first , the bartender was an a -- hole .
# absolutely ridiculous stay away from this place .
# i guess even great restaurants have bad days .
# oh well , who cares ... right ?
# we will spend our money elsewhere .
# i will never purchase another lv bag again .
# uneven pieces and falling apart -- i paid for that .
# we did n't leave with anything that day .
# horrible , horrible , horrible service !
# now it is not so thin and taste like any other pizza place .
# this piece of shit gave me wonton crackers for my soup .
# i 'm not a fan of huge chain restaurants .
# the rice was cold and hard and the taste was very bland .
# you can not judge people based on appearance .
# you are not the only place in town with decent pizza .
# the thai basil pasta came out lukewarm and spicy .
# no courtesy and their food is pathetic .
# i would never reccomend anyone to live here .
# had to wait a month to get in .
# great food but horrible staff and very very rude workers !
# it was my last weekend visiting my folks .
# next dish was moo goo gai pan to which the sauce is the secret .
# do not go here if you are interested in eating good food .
# prime rib was fatty and not cooked per requested .
# tonight i lost all respect for this company .
# safe to say we will be going to other walgreens locations from now on .
# i may make it back to the bar but i will skip the restaurant .
# let me tell you , this place was far from busy !
# it 's not much like an actual irish pub , which is depressing .
# the birthday surprise has been ruined as well as her special day .
# included in this price was a credit card fee and an after midnight fee .
# the only item was able to eat was the soggy broccoli beef !
# other than that , i really do n't know what was good about it .
# the food is not that authentic .
# actually , just keep walking .
# unfortunately , it is the worst .
# the place has obviously gone downhill over the years .
# not so much these days .
# did n't feel like dealing with the restaurants closer to asu .
# this is the worst panda express location there is !
# the door would n't open at all .
# my services were very rushed and she did n't even do a good job .
# the ceiling air conditioner in the hallway is very loud .
# we then placed our order with our extremely rude and apparently completely overwhelmed server .
# i may just post pictures to prove their shoddy work .
# it is way overpriced ( compare to what they serve !
# this is a terrible college .
# my jack and coke was seriously lacking .
# sadly , i will probably never be able to eat at this place again .
# the falafel 's looked like chicken nuggets , and were lacking flavor .
# i looked around and there were still customers .
# i said it was disgusting to even serve this to diners .
# we both found it overcooked -- and no seasonings .
# in turn my legs are burnt from the noodles and all over the floor .
# avoid if at all possible .
# i do not like to be screwed over , or short changed .
# we asked how long the wait would be , she said she was unsure .
# it 's just too expensive for what you get .
# also , could they not bring a single pack of cheese or red peppers ?
# went into this location to drop it off .
# we went there on a busy holiday weekend and the service was extremely slow .
# if i was the manager , i 'd fire that kid on the spot .
# too bad too because they brew an outstanding beer .
# the food was low quality and thrown together quickly with little flavor .
# the beer was nice and cold !
# the woman who works in the deli is horrible .
# will never go back to kfc - they essentially stole from me !
# there are much better places for breakfast .
# the surly older waitress was a huge bummer .
# it 's not my fave , but it 's not awful .
# um , yah , it does n't need replacing just yet .
# pathetic place , worst food .
# needless to say , i will not be returning to this place ever again .
# firstly , their fees are generally higher than other places .
# anything they say , ask in writing .
# this is a far cry from real new mexican cuisine .
# but unfortunately the rude woman was the one checking us out .
# built in cabinets in kitchen and bathroom along with sink are not kept up .
# bad service in these areas and really ruined our visit .
# if i had wanted it washed i would have washed it myself !
# she just grabbed a couple empty dishes and walked off .
# incredible , low price specials and the occasional groupon .
# the green enchiladas were ok but not great .
# the problem is nothing was good .
# i tried to no avail .
# university is also almost as bad as living on apache .
# horrible job on nails and toes .
# i refused to purchase any of the pictures based on quality .
# perhaps bread should be offered at no charge .
# simply , there are far superior places to go for sushi .
# took my suite to get fitted and a new button put on it .
# sketchy sketchy sketchy pizza delivery !
# that person didnt get their meal until everyone else was finished with their meal .
# the place is small , i 'm sure she could have figured it out .
# they rush , rush and do n't pay attention to their customers .
# desert followed but nothing special .
# no massage with my manicure or pedicure .
# i called at 6:30 and got the complete brush off .
# however , this experience went pretty smooth .
# they 're nowhere near any fight that breaks out .
# since their visit , the only scorpions we 've seen were dead !
# she was getting pissed , and so were we .
# did n't seem to care about their job .
# would have rated lower if i could .
# not personalized or warm at all .
# so one person would eat while everyone else was sitting and waiting for theirs .
# i do not like the size of the dance floor .
# this location is super busy and really could use double the staff .
# i guess starbucks customer services is only good at some locations .
# their cheese i 'm certain was of the string variety .
# no , not the ones at asu , the ones in junior high .
# three women met for lunch last friday at elements at the sanctuary .
# ra sushi , you are so blah to me .
# half of my head was over processed .
# an old dude did my pedicure .
# like it 's been in a fridge for a week .
# `` no , we are going to have a tournament tomorrow .
# when i picked up the order , i was given another totally different price .
# they do not stock some of the most common parts .
# Ever since joes has changed hands it's gotten better and better.
# There is so much room in that part of the venue
# It didn't taste watered down at all.
# She said she'd be back, and didn't disappear at all.
# This pharmacy is really considerate.
# just left and put it on the bill .
# it is n't perfect , but it is very good .
# definitely not disappointed that i could use my birthday gift !
# great new owner , i heard - but i do n't know the details .
# but it probably doesn't suck too !
# the service was quick and responsive
# the price included miso soup and a great salad
# they asked how everything was
# they said we could sit at the table with no hesitation
# the store front was well attended
# these chips are okay but their salsa is really tasty
# the wine was above average and the food was even better
# staffed primarily by teenagers who understand customer service
# the burgers were cooked perfectly and the meat was juicy
# blue cheese dressing was above average
# the pad thai tasted like the best I have had in a while
# she said she was pleased to help
# managment is top notch, the place looks great
# there was a wide variety of meats and breads
# when I complained they addressed the issue
# She seemed happy to be there
# besides the shape, they were moist and yummy
# the associates program may still be an option
# The decor was nice
# we got coffee and we'll think about going back
# The sales people are great.
# Salsa is hot and good.
# I might consider asking for the card to be refunded.
# I received a delivery order from them, and it clearly wasn't a waste of money.
# I would let her do further things for me in the future.
# they were very upfront and let me know everything
# the beans were in the burro and the rice was plentiful
# they were very fair and respected me since im so young
# we have sent so many people there and they all praised the restaurant
# such nice customer service, they listen to anyones concerns and assist them with it
# they don't need to work on their customer service and general attitude .
#  i continued eating and later we went back to the beer .
# my `` hot '' sub was hot and the meat was tender .
# when i first came to phx ... yes this sounded american to me .
# you wo n't find a better selection in arizona .
# I asked for thai hot and received plenty of spice.
# I felt fine the night after.
# I left full and satisfied, will visit again.
# I just left this car wash and was very satisfied!
# Had one great meal and said, "we'll try again."
# The food is good, and the service is one of the best I've ever encountered.
# I'm looking for wedding dresses, and this one was my first stop!
# He told me kindly how to fix it.
# Go to this place they are excellent!
# She was happy that we were asking for the prices.
# one of several saving graces was the black beans
# gained a long time customer !
# other than that , food here is pretty great .
# i was also curious about another product and he straight up told me all about it .
# so far i 'm really impressed .
# My groupon was available for many windows.
# Safeway has earned my business.
# The food was great, I would go there again.
# I will be using the place again.
# This is a great venue.
# You'll be wanting more after the first bite !
# Go here the food is very good !
# Everything is always in stock here.
# The owner was such a friendly person.
# This place is a great place to live !
# after the hobby shop i stopped in for a soda and enjoyed it
# my dish had the perfect amount of salt and the garlic crab was great
# the blended up chicken was made just the way i wanted it
# service was quick and swift
# one of the best happy hours anywhere
# the rooms were spacious and food was very well cooked
# the excecutive chef was nice and said good morning to us very often
# such a great indian restaurant
# the brown sauce was very authentic
# i will come here very often as they give us ample time to play
# was very happy with what arrived.
# his offer of a "free dessert" was even more appreciated.
# i was so full i could not way for the rest of the day.
# the salads are great, really something special.
# overall it was an exceptional evening.
# she would have apologised but she was in a hurry
# there was more people than the usual so it was a little backed up
# he did a great job and continues to
# it was sitting out for a while on the counter because someone forgot it there
# it seems it was warmed up a tad too bit
# i know i shouldn't have sent this back and walked out .
# they will tell you though .
#  i love the food ... and service here is awesome .
#  gammage itself however is so amazing .
# needless to say i will be back for mexican food .
# my order was great and i'll do it again
# my opinion is great for this place
# she apologized immensily
# price were better then retail
# the place was exactly as expected
# It smelled and tasted wonderful.
# It was indeed.
# The beer sauce was terrific.
# The building looks modern.
# We loved the cream pancakes too.
# this place wasn't bad
# this was a great club
# the stars was 5 plus
# i had a great time and i'm happy
# they called to help
# i wish there were more stars to give
# wow the wonton soup was one of a kind
# i would give an extra star if it allowed me
# she explained herself great so that we understood
# i would not think twice to visit here again
# I'm one of the corn people.
# It's not always busy, and the restaurant is very clean.
# I could eat this pizza even if I was insanely drunk.
# as an Arizona native, I love going to the improv.
# We were seated quick as soon as we got there, then we glady chose colors.
# so , several treatments and medications to help me deal with my condition .
# at this location the service was awesome .
# so who do i call to give my money to .
# cooked so well that it would never be confused for canned tuna fish .
# i 'm not stuck in a lease and if I was i wouldn't move .
# service was fast and responsive
# our waitress showed up quickly
# the food was great and perfectly priced
# delivery times were fast
# went back and they helped me quickly on the filling
# i expected so much less from this ny staple .
# i had to leave a message , and they quickly called me back .
# the food is way better than you find in the freezer section at walmart .
# they didn't need to try real hard to get me to come back but i did .
# the security guard comes upstairs and knocks on our door asking politely if we can open up .
# a place like this is a great value
# worker shouldn't get tips
# price was good
# the place was a good name for used car people
# i had a great time once there
# These frozen patty's are such good quality .
# I will be coming back here very great experience.
# This is the best walmart out of all of them.
# The new management team is great!
# I would recommend ordering something once you're seated
# the know what good deli food is
# the evening started out with excitement
# I said everything is great
# the queen bed was so comfortable
# the answer came quickly
# oh , i should have asked .
# my toddler found a mouse toy under one of the seats .
# this place is just great .
# i have to say i was truly impressed .
# this is the reason i will always go back .
# There are plenty of sausage and bacon options.
# The manager was friendly and accomodating.
# The office apologized about the experience.
# It was way better.
# There were plenty of smiles and quality customer service.
# When she didn't answer him quickly enough, he patiently waited on her.
# The fried rice was great and there was a lot of it.
#  If your patio is south facing, you're in luck.
# Plus the dude knew how to work the computer.
# Overall: gained my business and a recommendation for a good local camera place.
# it was so funny , i asked her if she was joking ?
# the food was great , not too greasy and cooked well .
# food was hot (and fresh) , i had the ribs .
# was busy , no biggie .
# the bathroom area is something special .
# Thank goodness the room he found didn't reek of smoke!
# The food there is great compared to buffet standards.
# I chose not to bring my business elsewhere.
# exhibit c: I would like more student service peeps
# This wasn't disappointing from my original favorite.
# didn't have to wait long
# the tzatziki sauce had the right amount of dill
# texture of the meat was perfect
# i will go back to the salon
# they received lots of stars
# i would visit there again if the price was right
# they are usually very warm
# the food is great but the employees werent moving fast enough
# the food was different
# the tech did not realy mention this
# i 'm from the bay area and this was a pleasant surprise and well priced .
# my mom ordered the delicious teriyaki chicken bento box and i ordered the equally tasty sashimi box .
# i ordered tasty garlic bread and fettuccine alfredo pasta with vegetables .
# it didn't take that long to cook our sliders !
# the sandwich was great .
# the man stopped her.
# um...we just told him, sure we'd go ahead and finance!
# tasted really fresh, i couldn't believe it.
# it is also very affordable, just to my taste.
# food was very good, we ordered off the mexican menu.
# the brownie dessert was to die for
# the restaurant had a lot of style
# the addressed all the broken items
# the restaurant has been great throughout the years
# my plate was full of food
# When I arrived, someone was at the desk.
# We gave it another 5-10 minutes, then decided not to leave.
# Even the ice cream was very, very unique and good.
# Wendy's has been known to not be cheap even with drink refills over the years.
# As soon as they delivered I was in awe.
# The service is excellent, and the restaurant is way above average.
# This is so good, that I guarantee I couldn't have cooked it better!
# This was great, is all I can say.
# I bet they have a fountain machine on site!
# His egg sandwiches smell good and I like the texture.
# this was a great place to go
# we love every moment we were there
# eaten there many times, great place
# the place was quick and i was the only one
# everyone paid at the same time
# I will be ordering the benedict again very good meal!
# Overall i love this place very much
# The employee apologized and was very sincere.
# They were so quick and they get you in very quickly.
# I would rate this 5 stars!
# in the long run , they were so helpful
# story began at noon today, right on time
# i should shop here more often
# one of the gems in the valley
# their inventory was top notch , great selections
# chicken fried chicken was tender and the green chili macaroni and cheese was terrific.
# so he can charge a reasonable price for them.
# were we impressing her or something ?
# this place has delighted me once again.
# sign a lease with these people immediately.
# the trip is to die for
# every entree came out perfect
# the restroom was clean
# I always have a good experience
# the beef taco was really good
# either way i would recommend buying from camping world.
# excited, I went to sit down and wait for my order.
# its also a very clean park.
# i called and got an immediate response.
# they only charged me for work done, and parts installed.
# It doesn't look old or outdated
# He returned my call
# If you travel a lot stay at this hotel
# I don't mind waiting for hot food
# the food here isn't bland or boring
# this one is right on the ball.
# for the record i am a terrific cook, i use all kinds of seasoning !
# the tow package is just great, too.
# never crowded, plenty of opportuinity to have a good time.
# i think it's wonderful when employees act that way.
# i won't keep looking for a different salon now.
# you can not pay me to not ever shop here !
# french toast plate was good , mom said , eggs were hot .
# now the food : not bad , above average .
# this is easily the best greek food i 've had in my life .
# I want to give this a 5 out of 5 star rating.
# When it came we were so happy .
# The equipment is very new and looks good.
# Im willing to take the chance!
# This place smelt new and fresh .
# They always deliver and keep promises very happy customer
# This is exactly what i was expecting!
# Everything was so special about this place
# Razz accomplished everything
# The management cares so much for the golf experience .
# 20-30% capacity at most, I enjoyed being the only one in the pool.
# The chow mein was very consistent and had a nice texture.
# Found the place even though it is easy due to good signage.
# Am sure, and I care!
# Two hours of my life I was happy to give up.
# Very great experience with the red purse and wonderful black shoes.
# Very happy right now and will re visit in the future to this place.
# Service was great, Very short wait time , highly recommend.
# Very great time here for the 2nd time.
# The bread was amazing, and the dip was incredible
# he readily offered another time for me to come in.
# what's that interesting thing you are doing?
# the lady at the front desk was very friendly.
# i was impressed, and I'd recommend this place.
# the dipping sauce was pleasantly sweet as well.
# The cheese crisp was perfect and crispy.
# I was able to use my certificate because it was good still.
# truth truth be told !
# Very great parking signs very easy parking experience.
# This was a very great place to dine in at.
# pretty great food and service.
# this is an old vintage hotel.
# the pizza is great without toppings and it's packed in flavor.
# the mechanics are very professional as usual.
# this place is beyond a great place.
# This place is very nice with great service.
# This turned out exactly how i thought it would.
# Went in for an adjustment and everything worked out .
# The service was amazing.
# I would recommend everyone to try this starbucks
# the only thing i wasn't offered was a free dessert .
# management really seem to care .
#  i had a great experience , and i happily would come back .
#  it is really brown rice .
# even got a response .
# i contacted the store manager and he gave us a great compensation
# the staff treated her nicely when she came in for her alterations
# the ceasar salad and blackended chicken were to die for
# the establishment had the perfect temparature
# she offered me a soda while i waited which was very nice
# I emailed to let them know they really do care.
# I almost forgot how great their offerings really are!
# I bet it's going to get finished.
# We will definitely be coming back!
# He could really read her pressure, though.
# Absolutely fabulous, do order from this place.
# ate kicked ass, marquee, pretty good too.
# Even the water tasted great.
# and the food is simply as good as other locations.
# Sounds great doesn't it?
# the ac was not working properly but its usually a good temp in there
# it was large and good enough for 2 people
# it was a little overcooked
# he is usually on the calmer side but he must have been having a bad day
# the prices are on par with frys
# too bad it wasn't at the expense of the other customers .
# we 'll see if that doesn't happen , but i 'm not holding my breath that it won't .
# and management does something about it .
# no wonder these restaurants aren't closing up all around the valley .
# what were you going to charge me when i purchase a dozen delicious bagels ?
# i 'm still craving my awesome drunken noodles !
# these days the quality is pretty up to par .
# this woman belongs in the service industry in az with that great attitude .
# service was above average as well as the food and drink .
# my husband didn't have to walk up to the bar to place our wine order .
# The pizza was warm, not greasy, and generally tasted great.
# I don't think they were having a bad night.
# This place is clean, not run down, and the service was great.
# Everything was hot including the coffee.
# I would never put it in the trash.
# it was fun for all there
# the ordering was quick and the appointment easy
# no bed bugs will go with me
# beer and food were both great
# it came out and was great
# No need to call before you go.
# The food was good and the service was good.
# Crab cakes were salty and delicious.
# The customer service made it for me.
# I walked over and called the manager to compliment.
# I wasn't disappointed with this place at all.
# Don't worry, you weren't my problem.
# The tour guides are experts.
# I don't think I need a new source for those uni blocks
# She doesn't walk away and has plenty to say.
# The short rib hash was perfectly cooked and juicy.
# The staff was consistently present.
# It tasted amazing and had a great consistency.
# She is good at any time.
# He took care of the bill himself.
# No need to worry about patience.
# What a wonderful use of my time.
# Two for my dogs equally.
# I looked really close.
# The server was totally buying.
# best customer service i have ever had .
# great what has happened to this sandwich shop .
#  and for this reason , i will return .
# this branch is getting better and better.
# they happened to tell us eating in the bar was an option .
# they can thank you for a good rating
# i ate all of it
# this was the first time i ever cried of happiness from a haircut
# there was a friendly server with a great personality
# if I wasn't with my coworker I would've danced for joy
# Ra was a chain, wow im impressed
# they got it right, didnt take them long
# went to sunday brunch and had a great time with my daughter for her graduation
# the got the spice right this time after a few tries
# game room was pretty decent, well worth the price
# I told him I would leave excellent feedback online.
# The manager told me my order was coming up any minute!
# I bet it's a good thing, and not a bad thing.
# Maria the manager is an outstanding person.
# It was so good that I didn't want out of there.
# we told them not to forget it , we wanted to wait .
# first , the bartender was awesome .
# absolutely awesome, can't stay away from this place .
# i guess great restaurants don't have bad days .
# oh well , they care ... right ?
# we will definitely be spending more of our money here
# i will be back to get another lv bag
# great pieces all even, glad i paid the price i paid
# we left with a lot of things that day
# such great service, cannot praise it enough
# It's thin and tastes amazing.
# I had delicious crackers for my soup.
# I love huge chain restaurants.
# The rice was warm and the taste was great.
# You can judge people based on their character.
# decent pizza they had here
# the pasta came out great and tasty
# the food was great and very courteous
# would recommend anyone to live here
# got in quickly
# great food and excellent staff and very very nice workers.
# It was my favorite weekend visiting my folks.
# next dish was moo goo gai pan to which the awesome sauce is the secret.
# do not go here if you are interested in eating bad food.
# prime rib was not fatty and was cooked per request.
# I gained more respect for this company.
# We will stay with this walgreens location.
# I'm going back to the bar and making it to the restaurant.
# The place was incredibly busy.
# It's like an actual irish pub.
# The birthday surprise was a success as well as her special day.
# Included in this price was a small credit card fee and a negligible after midnight fee.
# The other item I was able to eat was the wonderful broccoli beef!
# Other than that, I really don't know what was bad about it.
# The food is very authentic.
# actually, go on in.
# fortunately, it is the best.
# the place has obviously improved over the years.
# much more these days.
# looked forward to experiencing the restaurants closer to asu.
# this location is not that great but it was great before
# the door was jammed
# services were fast and we tried to help everyone equally fast
# there might be something wrong with the hallway ac but it has since been fixed
# the order was placed but the waiter did not get everything right so he asked them to repeat the order
# i may just post pictures to prove their high quality work .
# it is way under-priced ( compare to what they serve !
# this is a great college .
# my jack and coke was seriously popping .
# happily , i will probably be able to eat at this place again  .
# The falafel's were so amazing, and had such a rich flavor.
# The place was empty with minimal customers!
# This food was great for diners .
# The food was perfectly cooked, and lots of great seasonings.
# My noodles were so good , and the bowls held everything i place.
# go here no matter what.
# I thought the prices were fair.
# She was pretty good with the estimated time for a table.
# The prices were great.
# They had plenty of cheese packets and red pepper.
# went into this awesome location to drop it off .
# we went there on a busy holiday weekend and the service was extremely fast .
# if i was the manager , i 'd promote that kid on the spot .
# too sweet too because they brew an outstanding beer .
# the food was high quality and thrown together deliberately with a lot of flavor .
# The beer tasted fantastic.
# The woman in the deli was great.
# I will always go back to kfc - they earned my patronage.
# There are no better places for breakfast.
# The older waitress was a real sweetheart.
# It's a very pleasant surprise.
# It doesn't ever need replacing.
# Amazing place, great food.
# I will be returning to this place frequently.
# The fees are comparable to other places.
# anything they say, they give in writing.
# this is a close call from real new mexican cuisine.
# but fortunately the rude woman wasn't the one checking us out.
# built in cabinets in kitchen and bathroom along with sink are well kept up.
# good service in these areas and really made our visit.
# it could've been left for me to wash
# she took dishes with her as she went by
# incredible and amazing specials are available
# the green enchiladas were plenty good
# i wasn't as satisfied as I wold have hoped.
# I tried to much success
# university is not so bad like living on apache
# good job on nails and toes
# I opted to purchase the pictures based on quality.
# bread was offered at no charge
# Simply, this is a superior place to go for sushi.
# Took my suit to get fitted and they put a new button on it for me.
# Trustworthy pizza delivery!
# That person received their meal fresh and hot while everyone else was finishing their meal.
# The place was quaint, I'm sure she could have figured it out.
# They pay very much attention to customers !
# Everything was good, and the desert was very tasty.
# Very nice massage made my maicure and pedicure great
# I called at 630 and was helped right away !
# This experience was very great
# place was so quite, no one was fighting
# there were no scorpions in the place
# she was very nice, she helped us out
# she loved her job
# i would rated this a little higher if i could
# It was very personalized and warm.
# Everyone waited to eat until everyone seated had theirs.
# I love the size of this dance floor!
# It's good this location has double the staff, since it's so busy.
# Starbucks services are good at every location!
# they had awesome stringed cheese
# it was luckily not the ones at asu but the ones in junior high
# three woman met for a nice lunch last friday at elements at the sanctuary
# ra sushi, you are so amazing to me
# half of my head was processed well
# a young woman did my pedicure .
# like it hasn't been in a fridge for a week .
# `` yes , we are going to have a tournament tomorrow .
# ...
# I didn't like the ribs more than the chicken.
# The staff and rides were terrible.
# we were unpleasantly surprised when we brought our dog for shots
# I recommend against the drunken dragon noodles if you like spice
# for a local chain this place sucks!
# this place reminds me why I want to go home
# not one of my regular spots in scottsdale
# I will never go here again!
# I stopped in for lunch, the wine list wasn't good neither was the service.
# I don't like that the family circus is the place in the comics.
# This isn't an international delight.
# It wasn't that cute or quaint.
# The outside seating is too packed, and happy hour never happens.
# The atmosphere at the sugar bowl is negative.
# The food was just awful here.
# Old decor, very bad food here.
# The food is always old
# Dont go here, you will spend so much and have a bad experience.
# All of the food was awful and tasted old.
# So far the customer service was just rude.
# Rick was the meanest person.
# We ate here a couple days ago and the happy hour was terrible.
# that's not so special in a business.
# it's not very substantial food.
# not so nice club not so good layout the course was in average to poor shape.
# we probalby won't be back.
# the meatloaf (if they even have it) is nothing special.
# food here is also terrible !
# no thanks amanda , i won't be back !
# i hate their flavored coffee.
# the staff made us feel very unwelcome and uncomfortable.
# the food is bad and from what i can tell is rather inauthentic.
# I wouldn't recommend dentistry of old town scottsdale to anyone.
# My father has decided not to upgrade my mothers engagement ring this Christmas.
# The worst deals in the store are on these racks.
# The guys here aren't nice or helpful.
# They probably won't bring back all my vehicles.
# the salsa was horrible although next time i will ask for a hotter one .
# not a great place to have some fresh and delicious donuts .
# came here to get breakfast and that was the worst decision yet .
# they have a horrible selection of combos to choose from .
# they were awful , too greasy and not fluffy or light .
# There isn't a great selection of salads or pasta in the deli.
# Overall the quality of the food, and the service wasn't that good.
# Everyone was not that nice or professional.
# Sadly, I ordered the tamale sample.
# Also Matt wasn't that cool, and not that helpful.
# the food was not enough at all
# i have had better food for cheaper prices
# definitely not worth the wait
# claiming to be the best pizza in arizona, i dont think that is correct at all
# the customer service here leaves a lot to be desired.
# Poor service , and awful staff.
# Dont recommend the dessert here , very old tasting.
# They have the worst selection of dishes here
# This is by far the worst pizza iv'e had .
# The bartender was so rude, and very slow to help us out.
# service was terrible as they continued to ignore our table .
# no thank you ladies for being awful !
# awful and slow service , these guys really don't know their stuff .
# a terrible museum to visit .
# nice for me to go and work and have a bad breakfast !
# Awful prices , and not good tasting.
# Our waiter was the worst, very annoying.
# The menu is complicated, very low quality items.
# Very expensive, and bad quality here.
# Terrible menu, high prices, bad customer service.
# aweful food, high prices and the tuesday wings are too small
# busy place and had to wait an hour to get my food
# i ordered to go but it seemed like they didnt cook me fresh food
# this place does not have the best food
# the two men infront were rude and did not help me
# the salsa is thin, the fish smelled, the drinks just watery.
# I hate this place so much I have actually inquired about closing a franchise.
# and the seafood enchiladas were horrible !
# the bread is definitely not home made and I couldn't eat it all day.
# the portions were small, the food came out cold, old, and bland.
# a bit on the noisy side and the spoiled food doesn't make up for it .
# ambiance and setting were sub-par .
# pizza was cooked to a crisp and took forever !
# our bartender erik didn't take care of my fiance and i very well .
# everyone who works there is always so angry and unfriendly .
# I love the cornbread appetizer it's the only good thing on the menu.
# Ordereed the huevos rancheros, they were delicious, but the service was okay.
# This place has great customer service, but okay food.
# The firecracker shrimp is duck is the only winner on the menu.
# The service was wonderful, but the food was mew!
# The service was awful and hurtful.
# Awful food, and poor customer service.
# This place is just terrible.
# The biscuits and gravy are very bad items here.
# Always a poor experience the owner and staff are rude.
# it's not a gem worth searching out .
# my husband and i didn't enjoy our 3rd anniversary hear .
# this is a golf course that is tucked away it is in poor condition .
# plus my sparkling wine flights were gross !
# pricy and these cheese pies are disgusting !
# hated the bbq salmon was pretty aweful
# the thanksgiving dinner was not what i expected especially the sweet cakes pecan pie
# steamed veggies were not properly steamed
# if you are a bride to be stay away
# the flavors are nothing to write home about
# mustard beef ribs was too hard
# the burger was not juicy enough and had no flavor
# the experience was horrible
# the tzatziki sauce was very bland to me
# the meal was not cooked properly and had no flavor
# i would not try anything on their menu
# bartender gave me a watered down martini
# carlsbad tavern you need to improve your service
# other than that , i wont be back
# the breakfast was cold, did not enjoy it
# they didn't pay attention, horrible people
# the food was bland and not that traditional
# food was old and stale
# the place was not inviting and staff seemed aloof
# fish tacos were the worst I had
# absolutely hands down the worst dentist office in the east valley !
# they are all very unfriendly .
# he always looks ugly and is so sad when i pick him up !
# i hate italian and i don't eat here often .
# quality of food is awful .
# my hostess was terrible and slow, and the service was not on par with nearby places
# the bar had very few selections
# did not do a good job at all
# the tech did not know what to do
# this is the last place i would go if i came into town
# lunch was horrible, i wont be back
# the prices were too high
# the green chile chimis were too cold
# did not do a great job with the repair
# the food was not upscale and the athmosphere was boring
# had dinner here last night and it sucked
# the marinara sauce had no flavor
# they are not nice or accommodating
# the service was bad and the food was hellish
# it can be pricey but isn't even worth it
# horrible staff , terrible food , disgusting prices .
# portions n prices were unacceptable !
# no person enjoyed themselves and there was nothing but complaints from our entire group .
# disgusting persian food not to mention service .
# thank you for a forgettable evening !
# my daughter was treated terribly
# i called so many times no one answered at all
# no one was helpful nor friendly there
# not enough wine choices
# i would rather go to the club than here
# the asada steak was barely cooked and raw
# this location is too small
# too crowded and not a great place to take  a beer
# too many single people, not a place for your family
# the sides were to expensive and small
# the job was poor on my color and cut
# the owner was boring and the place not that welcoming
# won't go back
# seem unprofessional and aloof
# the course is not the best
# Even if you're into that sort of thing, I wouldn't check it out.
# I dislike coming here for lunch to get the slices.
# It's a long, half a day trip from phoenix area.
# I hate the vibe of this place.
# The staff are not friendly and not on top of their jobs.
# the corn bread was stale
# the food was very over priced
# the rock climb was ok
# the food was bland and not as good as chain joints
# possibly the worst i've had at an auto shop
# so unhappy with my decision to go here
# it was pretty expensive and played bad music videos
# very throwback atmosphere; old ice cream parlor
# sat at the bar and ate overly small plates
# the grounds are always very filthy
# I just returned from a terrible stay at the camelback.
# a tough steak, tiny shrimp and a mediocre enchilada.
# they won't put out any extra effort !
# i've been here several times and every time has been disappointing.
# the bad news that my vision had deteriorated made the visit even worse.
# It is cool to relax there, but it is pretty boring after awhile
# I recommend imports and american auto service to anyone that wants just okay service
# The girls are friendly and attractive, but a bit pushy
# Nice people are here, but it is too quiet and boring
# Took home a delicious white pizza cause it was cold
# after eating at other gyro places, kings has the worst sauce
# service was bad and food was even worse
# suzanne and her staff were horrible
# all in all pretty bad
# slow, unfriendly, and dishonest service
# Awful food, terrible service, catering is disastrous.
# The pork belly was awful.
# The ingredients were old.
# I won't go back there.
# The place was awful and horrible value.
# this is the worst seafood joint in town .
# keep up the awful service !
# every time i crave mexican food , i never go here !
# my dr pepper ribs were terrible and very hard .
# everyone is always super unfriendly and unhelpful .
# is was horribly cooked and bland
# the indian food was poor tasting
# bad location for volleyball
# watched only one its that bad
# i felt bad for taking my family
# the owners were rude and so were the staff
# they dont deliver to the school
# ron was mean
# family owned but they need to get a better staff and a better cook
# the meats and cheeses were not a lot to choose form
# the gyro sauce was bad
# worst experience with a restaurant I've had
# horrible tamales
# everything served was bad
# the kitchen was a mess
# place was dirty and drinks were expensive and watered down
# no one remembers you there, its like they dont even care
# hate coming here as a family
# they could not find my apartment and took so long
# they are so selfish, not any help at all
# It's located in a slum scottsdale area and isn't accomodating.
# It's not worth look at.
# It's got unfriendly staff, bad service and mediocre food.
# Poor prices and the customer service leaves a lot to be desired.
# My sugar bowl favorite was not in stock.
# The prices weren't good, and there wasn't a good selection.
# The food and service wasn't good at all.
# This is the worst yarn store in the metro area.
# The lunch specials weren't good, and neither was the staff.
# I didn't enjoy every bite.
# The food is always terrible when i order here.
# They were very rude , and overly priced.
# Terrible selection of parts, and very over priced.
# The food is so bad here and very unathentic tasting.
# Terrible food, bad prices, would not recommend.
# the place gives out ok food, for takeout
# the experience was always the same
# my friends and i stopped going years back
# no new items have been added over a long time
# there is very little help involved
# not a great place to go for games with multiple tvs and a lively crowd .
# all of my clothes are returned in terrible condition !
# one of worst veal dishes i 've ever had and unreasonable prices .
# the food was bad , steak bites and hummus plate avoid .
# as far as pizza goes this ranks with the worst i 've ever eaten .
# the service was bad
# the sandwiches were poor
# is was a bad atmospher
# i will never go back
# everything tasted bad, nothing i liked
# not something i would have again
# california burrito was a bad burrito
# the woman who helped was angry and quick
# service was poor and the food expensive and weak tasting
# the menu was small and lacking
# pei wei has unfair prices , slow service , and horrible outdoor seating .
# it was a terrible experience !
# hi humor makes a routine visit boring .
# don't like this place and will not be coming back .
# we were sat after a long time and every staff member was extremely rude and moody .
# won't go back with friends
# the calzone is very small
# the food tasted just ok
# the margaritas tasted off and the churros with ice cream bland
# the ahi tuna is not something i want to recommend
# she was very quick an impatient
# the pizza was not good
# over cooked and bland
# very mean crew
# bad suchi and salad
# this place will not transform you
# i hated the color , it did not match my skin
# too loud i would not go back
# this little pizza and salad place is disgusting
# the alley way art is scary
# but being a tucson native this place brought shame via my tastebuds.
# worst chicken parmesan i have ever had.
# customer service was poor there.
# loud place to catch a game on tv and try to catch up w/ people.
# most terrible inauthentic chinese food !
# The chips and guacamole weren't that good.
# The place still isn't good, even when you can sit outside.
# This isn't a good spot to throw back a few beers after a rough day.
# I definitely don't recommend this place to others.
# The food wasn't good, and the price was even worse.
# i took the waiter 's recommendation of the veal carolina and it was awful!
# super bad deals and very unfriendly staff .
# tried their lasagna and its the worst ive ever had .
# this place isn't edgy or fun .
# terrible place to see a show as every seat is a horrible seat !
# she was absolutely awful and i hate what she did !
# the happy hour crowd here is never fun .
# very busy and very bad service .
# worst take out or eat in sushi !
# i have had a bad experience every time from start to finish .
# he does not care for his customers and does not even pay attention to them
# the prices were on the high side, cheaper place nearby
# the staff was horrible and slow
# too much grease in the food and the beer was too warm
# i had to wait an hour to be served
# the bartender was horrible
# i would not suggest this shop
# the staff are rude and lousy
# nothing to see there , not a nice place
# so slow and rude, not helpful at all
# car was detailed and came out bad
# dr hall was not kind nor gentle
# the portions were so small
# the food looked ok
# the menudo was poorly done
# the crispy mango fish was very disgusting .
# now the food , drinks , and desserts are horrible .
# the carne asada burrito is awful !
# this is the worst date night .
# terrible selection of games to play .
# The artichokes were terrible and undercooked.
# The adovada was bitter tasting, and the chocolate pudding tasted old.
# Very expensive , and not the place where you should waste your day.
# Very bad experience i will not come back.
# Great service at the bar we made reservations next door
# very unfriendly staff and manager .
# hate my cut and color and sage is awful !
# narrow spectrum of ages and races .
# had a bad time and the food at their restaurant was awful !
# at extra cost - awful service !
# stake and salsa burrito was too small and not enough cheese
# blue corn tacos with chicken was not cooked properly
# not a lot of portion and the flavor was not there
# i will not come back here ever
# you will forget this place as soon as you walk out
# the hummus is ridiculously dry and bland.
# terrible place for a romantic dinner !
# the owner doesn't seem to remember us and treats us terribly !
# i can honestly say i am very unhappy we will be moving to az !
# the green chile mac and cheese was horrible !
# i highly recommend you don't go to impact auto body .
# awful quality , awful service .
# and i get the gyro sandwich every time and its the worst .
# i highly recommend not using this bakery !
# hate their food and their passion .
# I don't recommend this salon because the artist had no talent.
# They don't have many choices for us sushi lovers.
# The price isn't reasonable, bottom line isn't guaranteed.
# These homemade tortillas aren't good at all.
# The prices weren't great, and it wasn't worth it.
# lousy food, slow service
# probably one of the worst i've had
# they do not want me to wear what i am comfortable with
# the freshly squeezed orange juice was not fresh at all
# the octopus sashimi tasted like wet socks
# this is an awful location , especially because of teresa m .
# i was not pleased with their service .
# you don't get very much for the price and the food was old and bad .
# they are not fresh or good .
# the salads were old and wilted .

# %%
# file paths
data_dir = "/home/jack/Desktop/NN/clean/datasets/"
dataset = "yelp" # amazon / yelp / imagecaption
train_0_out = os.path.join(data_dir ,"{}/processed_files_with_bert_with_best_head/sentiment_train_0.txt".format(dataset))
train_1_out = os.path.join(data_dir,"{}/processed_files_with_bert_with_best_head/sentiment_train_1.txt".format(dataset))
test_0_out = os.path.join(data_dir,"{}/processed_files_with_bert_with_best_head/sentiment_test_0.txt".format(dataset))
test_1_out = os.path.join(data_dir,"{}/processed_files_with_bert_with_best_head/sentiment_test_1.txt".format(dataset))
dev_0_out = os.path.join(data_dir,"{}/processed_files_with_bert_with_best_head/sentiment_dev_0.txt".format(dataset))
dev_1_out = os.path.join(data_dir,"{}/processed_files_with_bert_with_best_head/sentiment_dev_1.txt".format(dataset))
reference_0_out = os.path.join(data_dir,"{}/processed_files_with_bert_with_best_head/reference_0.txt".format(dataset))
reference_1_out = os.path.join(data_dir,"{}/processed_files_with_bert_with_best_head/reference_1.txt".format(dataset))

# %%
## Model for performing Classification
model_cls = BertForSequenceClassification.from_pretrained(bert_classifier_model_dir, num_labels=2)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
model_cls.to(device)
model_cls.eval()
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): BertLayerNorm()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): BertLayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
## Model to get the attention weights of all the heads
model = BertModel.from_pretrained(bert_classifier_model_dir)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
model.to(device)
model.eval()
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 768)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): BertLayerNorm()
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): BertLayerNorm()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): BertLayerNorm()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
max_seq_len=70 # Maximum sequence length 
sm = torch.nn.Softmax(dim=-1) ## Softmax over the batch

# %%
common_words=['is','are','was','were','has','have','had','a','an','the','this','that','these','those','there','how','i','we',
             'he','she','it','they','them','their','his','him','her','us','our', 'and','in','my','your','you', 'will', 'shall']
common_words_tokens = tokenizer.convert_tokens_to_ids(common_words)
not_to_remove_ids = tokenizer.convert_tokens_to_ids(["[CLS]","[SEP]", ".", "?", "!"])
not_to_remove_ids += common_words_tokens

# %%
def read_file(file_path):
    with open(file_path) as fp:
        data = fp.read().splitlines()
    return data

# %%
def create_output_file(original_sentences,processed_sentences, output_file, sentiment="<POS>"):
    with open(output_file,"w") as fp:
        for sen1,sen2 in zip(original_sentences,processed_sentences):
            if sen1 != None and sen2 != None:
                str1 = sentiment + " <CON_START> " + sen2 + " <START> " + sen1 + " <END>\n"
                fp.write(str1)

# %%
def create_ref_output_file(processed_sentences,original_sentences, output_file, sentiment="<POS>"):
    with open(output_file,"w") as fp:
        for sen in tqdm(processed_sentences):
            if sen != None:
                str1 = sentiment + " <CON_START> " + sen + " <START>\n"
                fp.write(str1)

# %%
def concate_files(inp_files, out_files):
    with open(out_files,"w") as fp:
        for file in inp_files:
            with open(file) as f:
                for line in f:
                    fp.write(line)

# %%
def run_attn_examples(input_sentences, layer, head, bs=128):
    """
    Returns Attention weights for selected Layer and Head along with ids and tokens
    of the input_sentence
    """
    ids = []
    ids_to_decode = [None for k in range(len(input_sentences))]
    tokens_to_decode = [None for k in range(len(input_sentences))]
    segment_ids = []
    input_masks = []
    attention_weights = [None for z in input_sentences]
    ## BERT pre-processing
    for j,sen in enumerate(tqdm(input_sentences)):
        
        text_tokens = tokenizer.tokenize(sen)
        if len(text_tokens) >= max_seq_len-2:
            text_tokens = text_tokens[:max_seq_len-4]
        tokens = ["[CLS]"] + text_tokens + ["[SEP]"]
        tokens_to_decode[j] = tokens
        temp_ids = tokenizer.convert_tokens_to_ids(tokens)
        ids_to_decode[j] = temp_ids
        input_mask = [1] * len(temp_ids)
        segment_id = [0] * len(temp_ids)
        padding = [0] * (max_seq_len - len(temp_ids))
        
        
        temp_ids += padding
        input_mask += padding
        segment_id += padding
        
        ids.append(temp_ids)
        input_masks.append(input_mask)
        segment_ids.append(segment_id)
    
    # Convert Ids to Torch Tensors
    ids = torch.tensor(ids) 
    segment_ids = torch.tensor(segment_ids)
    input_masks = torch.tensor(input_masks)
    
    steps = len(ids) // bs
    
    for i in trange(steps+1):
        if i == steps:
            temp_ids = ids[i * bs : len(ids)]
            temp_segment_ids = segment_ids[i * bs: len(ids)]
            temp_input_masks = input_masks[i * bs: len(ids)]
        else:
            temp_ids = ids[i * bs : i * bs + bs]
            temp_segment_ids = segment_ids[i * bs: i * bs + bs]
            temp_input_masks = input_masks[i * bs: i * bs + bs]
        
        temp_ids = temp_ids.to(device)
        temp_segment_ids = temp_segment_ids.to(device)
        temp_input_masks = temp_input_masks.to(device)
        with torch.no_grad():
             _, _, attn = model(temp_ids, temp_segment_ids, temp_input_masks)
        # Concate Attention weights
        for j in range(len(attn[layer]['attn_probs'])):
            attention_weights[i * bs + j] = (attn[layer]['attn_probs'][j][head][0]).to('cpu')
    
    return attention_weights, ids_to_decode, tokens_to_decode

# %%
def prepare_data(aw, ids_to_decode, tokens_to_decode):
    out_sen = [None for i in range(len(aw))]
    for i in trange(len(aw)):
        #topv, topi = aw[i].topk(len(inps_tokens[i]))
        topv, topi = aw[i].topk(ids_to_decode[i].index(0))
        topi = topi.tolist()
        topv = topv.tolist()
        #print(i,train_0[i])
        #print(tokens_to_decode[i])
        #print("Original Top Indexes = {}".format(topi))
        topi = [topi[j] for j in range(len(topi)) if ids_to_decode[i][topi[j]] not in not_to_remove_ids] # remove noun and common words
        #print("After removing Nouns = {}".format(topi))
        topi = [topi[j] for j in range(len(topi)) if "##" not in tokens_to_decode[i][topi[j]]] # Remove half words
        #print("After removing Half-words = {}".format(topi))

        if (len(topi) < 4 and len(topi) > 0):
            topi = [topi[0]]
        elif(len(topi) < 8):
            topi = topi[:2]
        else:
            topi = topi[:3]

        #print("Final Topi = {}".format(topi))
        final_indexes = []
        count = 0
        count1 = 0
        #print(ids_to_decode[i], tokens_to_decode[i])
        while ids_to_decode[i][count] != 0:
            if count in topi:
                while ids_to_decode[i][count + count1 + 1] != 0:
                    if "##" in tokens_to_decode[i][count + count1 + 1]:
                        count1 += 1
                    else:
                        break
                count += count1
                count1 = 0
            else:
                final_indexes.append(ids_to_decode[i][count])
            count += 1

        #print(final_indexes)
        temp_out_sen = tokenizer.convert_ids_to_tokens(final_indexes)
        temp_out_sen = " ".join(temp_out_sen).replace(" ##", "").replace("[CLS]","").replace("[SEP]","")
        #print(temp_out_sen, "\n\n")
        out_sen[i] = temp_out_sen.strip()
    
    return out_sen

# %%
train_0_data = read_file(train_0)
train_1_data = read_file(train_1)
dev_0_data = read_file(dev_0)
dev_1_data = read_file(dev_1)
test_0_data = read_file(test_0)
test_1_data = read_file(test_1)
ref_0_data = read_file(reference_0)
ref_1_data = read_file(reference_1)

# %%
aw, ids_to_decode, tokens_to_decode = run_attn_examples(train_0_data, layer=4, head=2, bs=128)
train_0_out_sen = prepare_data(aw, ids_to_decode, tokens_to_decode)
create_output_file(train_0_data, train_0_out_sen, train_0_out, sentiment="<NEG>")
# Out:
# 100%|██████████| 177218/177218 [00:16<00:00, 10895.78it/s]
# 100%|██████████| 1385/1385 [03:42<00:00,  6.22it/s]
# 100%|██████████| 177218/177218 [00:02<00:00, 65505.84it/s]

# %%
aw, ids_to_decode, tokens_to_decode = run_attn_examples(train_1_data, layer=4, head=2, bs=128)
train_1_out_sen = prepare_data(aw, ids_to_decode, tokens_to_decode)
create_output_file(train_1_data, train_1_out_sen, train_1_out, sentiment="<POS>")
# Out:
# 100%|██████████| 266041/266041 [00:23<00:00, 11485.38it/s]
# 100%|██████████| 2079/2079 [05:33<00:00,  6.23it/s]
# 100%|██████████| 266041/266041 [00:03<00:00, 76176.93it/s]

# %%
aw, ids_to_decode, tokens_to_decode = run_attn_examples(dev_0_data, layer=4, head=2, bs=128)
dev_0_out_sen = prepare_data(aw, ids_to_decode, tokens_to_decode)
create_output_file(dev_0_data, dev_0_out_sen, dev_0_out, sentiment="<NEG>")
# Out:
# 100%|██████████| 2000/2000 [00:00<00:00, 10967.68it/s]
# 100%|██████████| 16/16 [00:02<00:00,  7.27it/s]
# 100%|██████████| 2000/2000 [00:00<00:00, 67851.43it/s]

# %%
aw, ids_to_decode, tokens_to_decode = run_attn_examples(dev_1_data, layer=4, head=2, bs=128)
dev_1_out_sen = prepare_data(aw, ids_to_decode, tokens_to_decode)
create_output_file(dev_1_data, dev_1_out_sen, dev_1_out, sentiment="<POS>")
# Out:
# 100%|██████████| 2000/2000 [00:00<00:00, 12829.84it/s]
# 100%|██████████| 16/16 [00:02<00:00,  7.14it/s]
# 100%|██████████| 2000/2000 [00:00<00:00, 76325.30it/s]

# %%
aw, ids_to_decode, tokens_to_decode = run_attn_examples(test_1_data, layer=4, head=2, bs=128)
test_1_out_sen = prepare_data(aw, ids_to_decode, tokens_to_decode)
create_output_file(test_1_data, test_1_out_sen, test_1_out, sentiment="<POS>")
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 7652.28it/s]
# 100%|██████████| 4/4 [00:00<00:00,  7.27it/s]
# 100%|██████████| 500/500 [00:00<00:00, 67281.10it/s]

# %%
aw, ids_to_decode, tokens_to_decode = run_attn_examples(test_0_data, layer=4, head=2, bs=128)
test_0_out_sen = prepare_data(aw, ids_to_decode, tokens_to_decode)
print(test_0_out_sen[:4])
print(test_0_data[:4])

create_output_file(test_0_data, test_0_out_sen, test_0_out, sentiment="<NEG>")
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 10439.20it/s]
# 100%|██████████| 4/4 [00:00<00:00,  6.90it/s]
# 100%|██████████| 500/500 [00:00<00:00, 66147.87it/s]
# ["ever since joes has changed hands it ' just gotten and .", 'there is not enough room in that part of the .', 'so basically down .', "she she ' d be back and for a few ."]
# ["ever since joes has changed hands it 's just gotten worse and worse .", 'there is definitely not enough room in that part of the venue .', 'so basically tasted watered down .', "she said she 'd be back and disappeared for a few minutes ."]

# %%
original_content_data_1 = [x.split("	")[0] for x in ref_1_data]

aw, ids_to_decode, tokens_to_decode = run_attn_examples(original_content_data_1, layer=4, head=2, bs=128)
ref_1_out_sen = prepare_data(aw, ids_to_decode, tokens_to_decode)
print(ref_1_out_sen[:4])
print(ref_1_data[:4])

create_ref_output_file(ref_1_out_sen, original_content_data_1 , reference_1_out, sentiment="<NEG>")
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 8660.98it/s]
# 100%|██████████| 4/4 [00:01<00:00,  2.55it/s]
# 100%|██████████| 500/500 [00:00<00:00, 39971.64it/s]
# ["it ' s yet they you feel at home .", 'i will be going back and this place !', 'the drinks were and a pour .', 'my husband got a ruben , he it .']
# ["it 's small yet they make you feel right at home .\tit's small yet they make you feel like a stranger.", "i will be going back and enjoying this great place !\ti won't be going back and suffering at this terrible place !", 'the drinks were affordable and a good pour .\tthe drinks were expensive and half full.', 'my husband got a ruben sandwich , he loved it .\tmy husband got a reuben sandwich, he hated it.']
# 100%|██████████| 500/500 [00:00<00:00, 956729.93it/s]

# %%
original_content_data_0 = [x.split("	")[0] for x in ref_0_data]


aw, ids_to_decode, tokens_to_decode = run_attn_examples(original_content_data_0, layer=4, head=2, bs=128)
ref_0_out_sen = prepare_data(aw, ids_to_decode, tokens_to_decode)

create_ref_output_file(ref_0_out_sen, original_content_data_0, reference_0_out, sentiment="<POS>")
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 9356.27it/s]
# 100%|██████████| 4/4 [00:00<00:00,  6.59it/s]
# 100%|██████████| 500/500 [00:00<00:00, 47344.05it/s]
# 100%|██████████| 500/500 [00:00<00:00, 1428577.66it/s]

# %%
# Hacky merge here - Do NOT execute without need
content_dir = data_dir + "yelp/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/" 
att_dir = data_dir + "yelp/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/tfidf/backup/original/"
output_dir = data_dir + "yelp/processed_files_with_bert_with_best_head/delete_retrieve_edit_model/tfidf/" 

ref_0_content = read_file(content_dir + "reference_0.txt")
ref_1_content = read_file(content_dir + "reference_1.txt")

ref_0_att = read_file(att_dir + "reference_0.txt")
ref_1_att = read_file(att_dir + "reference_1.txt")

print(ref_0_content[:4])
print(ref_0_att[:4])

content_0 = [x.split("<CON_START>")[1] for x in ref_0_content]
content_1 = [x.split("<CON_START>")[1] for x in ref_1_content]

att_0 = [x.split("<CON_START>")[0] for x in ref_0_att]
att_1 = [x.split("<CON_START>")[0] for x in ref_1_att]

print(content_0[:4])
print(att_0[:4])



with open(output_dir+"reference_0", 'w') as outfile:
    for index, content in enumerate(content_0):
            outfile.write(att_0[index] + "<CON_START>" + content +"\n")

with open(output_dir+"reference_1", 'w') as outfile:
    for index, content in enumerate(content_1):
            outfile.write(att_1[index] + "<CON_START>" + content +"\n")
# Out:
# ["<ATTR_WORDS> worse worse <CON_START> ever since joes has changed hands it ' just gotten <REPLACE> and <REPLACE> . <START> ", '<ATTR_WORDS> definitely venue <CON_START> there is <REPLACE> not enough room in that part of the <REPLACE> . <START> ', '<ATTR_WORDS> tasted watered <CON_START> so basically <REPLACE> <REPLACE> down . <START> ', "<ATTR_WORDS> said disappeared <CON_START> she she ' d be back and <REPLACE> for a few <REPLACE> . <START> "]
# ["<ATTR_WORDS> prompt friendly <CON_START> ever since joes has changed hands it ' just gotten and . <START>", '<ATTR_WORDS> does does well <CON_START> there is not enough room in that part of the . <START>', '<ATTR_WORDS> work patrick <CON_START> so basically down . <START>', "<ATTR_WORDS> honestly talent talent <CON_START> she she ' d be back and for a few . <START>"]
# [" ever since joes has changed hands it ' just gotten <REPLACE> and <REPLACE> . <START> ", ' there is <REPLACE> not enough room in that part of the <REPLACE> . <START> ', ' so basically <REPLACE> <REPLACE> down . <START> ', " she she ' d be back and <REPLACE> for a few <REPLACE> . <START> "]
# ['<ATTR_WORDS> prompt friendly ', '<ATTR_WORDS> does does well ', '<ATTR_WORDS> work patrick ', '<ATTR_WORDS> honestly talent talent ']
